# %%
import numpy as np
import os
import sys
import cv2
import matplotlib.pyplot as plt
import open3d as o3d
# %matplotlib inline 

src_path = os.path.abspath("../..")
if src_path not in sys.path:
    sys.path.append(src_path)
# %load_ext autoreload
from dataset.kitti_odometry_dataset import KittiOdometryDataset, KittiOdometryDatasetConfig
from dataset.filters.filter_list import FilterList
from dataset.filters.kitti_gt_mo_filter import KittiGTMovingObjectFilter
from dataset.filters.range_filter import RangeFilter
from dataset.filters.apply_pose import ApplyPose

import scipy
from scipy.spatial.distance import cdist
from normalized_cut import normalized_cut
from ncuts_utils import ncuts_chunk,kDTree_1NN_feature_reprojection_colors, get_merge_pcds
from dataset_utils import * 
from point_cloud_utils import get_pcd, transform_pcd, kDTree_1NN_feature_reprojection, remove_isolated_points, get_subpcd, get_statistical_inlier_indices, merge_chunks_unite_instances
from aggregate_pointcloud import aggregate_pointcloud
from visualization_utils import generate_random_colors, color_pcd_by_labels,generate_random_colors_map
from sam_label_distace import sam_label_distance
from chunk_generation import subsample_positions, chunks_from_pointcloud, indices_per_patch, tarl_features_per_patch, image_based_features_per_patch, dinov2_mean, get_indices_feature_reprojection
from metrics.metrics_class import Metrics
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [(0.267004, 0.004874, 0.329415), (0.277018, 0.050344, 0.375715), (0.282656, 0.100196, 0.42216), (0.28229, 0.145912, 0.46151), (0.276194, 0.190074, 0.493001), (0.265145, 0.232956, 0.516599), (0.252194, 0.269783, 0.531579), (0.235526, 0.309527, 0.542944), (0.21813, 0.347432, 0.550038), (0.201239, 0.38367, 0.554294), (0.185556, 0.41857, 0.556753), (0.171176, 0.45253, 0.557965), (0.159194, 0.482237, 0.558073), (0.14618, 0.515413, 0.556823), (0.133743, 0.548535, 0.553541), (0.123463, 0.581687, 0.547445), (0.119483, 0.614817, 0.537692), (0.128087, 0.647749, 0.523491), (0.150148, 0.676631, 0.506589), (0.19109, 0.708366, 0.482284), (0.24607, 0.73891, 0.452024), (0.311925, 0.767822, 0.415586), (0.386433, 0.794644, 0.372886), (0.468053, 0.818921, 0.323998), (0.545524, 0.838039, 0.275626), (0.636902, 0.856542, 0.21662), (0.730889, 0.871916, 0.156029), (0.82494, 0.88472, 0.106217), (0.916242, 0.896091, 0.100717), (0.993248, 0.906157, 0.143936)]

# %%
import sklearn

def intersect(pred_indices, gt_indices):
        intersection = np.intersect1d(pred_indices, gt_indices)
        return intersection.size / pred_indices.shape[0]


def remove_semantics(labels,preds):
        gt_idcs = np.where(labels == 0)[0]
        new_ncuts_labels = preds.copy()
        for i in np.unique(preds):
                pred_idcs = np.where(preds == i)[0]
                cur_intersect = intersect(pred_idcs,gt_idcs)
                if cur_intersect > 0.8:
                        new_ncuts_labels[pred_idcs] = 0
        return new_ncuts_labels



def color_pcd_by_labels(pcd, labels,colors=None,gt_labels=None):
    
    if colors == None : 
        colors = generate_random_colors(2000)
    pcd_colored = copy.deepcopy(pcd)
    pcd_colors = np.zeros(np.asarray(pcd.points).shape)
    if gt_labels is None :
    	unique_labels = list(np.unique(labels)) 
    else: 
        unique_labels = list(np.unique(gt_labels))
    
    background_color = np.array([0,0,0])


    #for i in range(len(pcd_colored.points)):
    for i in unique_labels:
        if i == -1 : 
            continue
        idcs = np.where(labels == i)
        idcs = idcs[0]
        if i == 0 : 
            pcd_colors[idcs] = background_color
        else : 
            try : 
                pcd_colors[idcs] = np.array(colors[unique_labels.index(i)])
            except : 
                import pdb; pdb.set_trace()
        
        #if labels[i] != (-1):
        #    pcd_colored.colors[i] = np.array(colors[labels[i]]) / 255
    pcd_colored.colors = o3d.utility.Vector3dVector(pcd_colors/ 255)
    return pcd_colored


def get_merge_pcds(out_folder_ncuts):
        point_clouds = []

        # List all files in the folder
        files = os.listdir(out_folder_ncuts)
        files.sort()

        # Filter files with a .pcd extension
        pcd_files = [file for file in files if file.endswith(".pcd")]
        print(pcd_files)
        # Load each point cloud and append to the list
        for pcd_file in pcd_files:
                file_path = os.path.join(out_folder_ncuts, pcd_file)
                point_cloud = o3d.io.read_point_cloud(file_path)
                point_clouds.append(point_cloud)
        return point_clouds

def uniform_down_sample_with_indices(points,every_k_points):
    # Create a new point cloud for the downsampled output
    
    # List to hold the indices of the points that are kept
    indices = []
    
    
    # Iterate over the points and keep every k-th point
    for i in range(0, points.shape[0], every_k_points):
        indices.append(i)

    
    return indices


def merge_unite_gt(chunks):
    last_chunk = chunks[0] 
    merge = o3d.geometry.PointCloud()
    merge += last_chunk

    for new_chunk in chunks[1:]:
        merge += new_chunk
    
    merge.remove_duplicated_points()
    return merge 

def downsample_chunk(points,chunk_preds_ncut,kitti_chunk_labels):
        num_points_to_sample = 60000
        every_k_points = int(kitti_chunk_labels.shape[0] /num_points_to_sample) 
        indeces = uniform_down_sample_with_indices(kitti_chunk_labels,every_k_points)

        points = points[indeces]
        chunk_preds_ncut = chunk_preds_ncut[indeces]
        kitti_chunk_labels = kitti_chunk_labels[indeces]
        return points,chunk_preds_ncut,kitti_chunk_labels

def divide_indices_into_chunks(max_index, chunk_size=200):
    chunks = []
    for start in range(0, max_index, chunk_size):
        end = min(start + chunk_size, max_index)
        chunks.append((start, end))
    return chunks

# %% [markdown]
# Here we define the dataset depending on kitti sequence!

# %%
DATASET_PATH = os.path.join('/media/cedric/Datasets1/semantic_kitti/')
import shutil 
import gc 

minor_voxel_size = 0.05
major_voxel_size = 0.35
chunk_size = np.array([25, 25, 25]) #meters
overlap = 24 #meters
ground_segmentation_method = 'patchwork' 
NCUT_ground = False 
out_folder_ncuts = 'test_data/'

out_folder = 'pcd_preprocessed/train_data/'
if os.path.exists(out_folder) == False : 
        os.makedirs(out_folder)

alpha = 1.0
theta = 0.5
colors = generate_random_colors_map(6000)
beta = 0.0
gamma = 0.0
proximity_threshold = 1.0

seqs = list(range(6,10))

for seq in seqs : 
        print("Sequence",seq)
        SEQUENCE_NUM = seq
        dataset = create_kitti_odometry_dataset(DATASET_PATH,SEQUENCE_NUM,ncuts_mode=True)
        chunks_idcs = divide_indices_into_chunks(len(dataset))
        
        
        data_store_folder = out_folder + str(SEQUENCE_NUM) + "/"
        if os.path.exists(data_store_folder) == False :
                        os.makedirs(data_store_folder)
        print("STORE FOLDER",data_store_folder)
        
        for cur_idx,cidcs in enumerate(chunks_idcs):
                #if cur_idx == 0 : 
                #         continue
        
                ind_start = cidcs[0]
                ind_end = cidcs[1]
                
                print('ind start',ind_start)
                print('ind end',ind_end)
                
                if os.path.exists(f'{out_folder}non_ground{SEQUENCE_NUM}_{cur_idx}.pcd') == False : 
                        print('process poses')
                        process_and_save_point_clouds(dataset,ind_start,ind_end,minor_voxel_size=minor_voxel_size,
                                                major_voxel_size=major_voxel_size,icp=False,
                                                out_folder=out_folder,sequence_num=SEQUENCE_NUM,
                                                ground_segmentation_method=ground_segmentation_method,cur_idx=cur_idx)
                
                if os.path.exists(f'{out_folder}pcd_nonground_minor{SEQUENCE_NUM}_{cur_idx}.pcd') == False : 
                #    if True == True : 
                        print('load and downsample points')
                        pcd_ground_minor, pcd_nonground_minor,\
                        all_poses, T_pcd, first_position,kitti_labels = load_and_downsample_point_clouds(out_folder,SEQUENCE_NUM,minor_voxel_size,\
                                                                                ground_mode=ground_segmentation_method,cur_idx=cur_idx)
                        
                        print('write pcds')
                        print(pcd_ground_minor)
                        o3d.io.write_point_cloud(f'{out_folder}pcd_ground_minor{SEQUENCE_NUM}_{cur_idx}.pcd', pcd_ground_minor, write_ascii=False, compressed=False, print_progress=True)
                        o3d.io.write_point_cloud(f'{out_folder}pcd_nonground_minor{SEQUENCE_NUM}_{cur_idx}.pcd', pcd_nonground_minor, write_ascii=False, compressed=False, print_progress=True)
                        print('write labels')
                        np.savez(f'{out_folder}kitti_labels_preprocessed{SEQUENCE_NUM}_{cur_idx}.npz',
                                                                instance_nonground=kitti_labels['instance_nonground'],
                                                                instance_ground=kitti_labels['instance_ground'],
                                                                seg_ground = kitti_labels['seg_ground'],
                                                                seg_nonground=kitti_labels['seg_nonground']
                                                                )
                print("load pcd")
                pcd_ground_minor = o3d.io.read_point_cloud(f'{out_folder}pcd_ground_minor{SEQUENCE_NUM}_{cur_idx}.pcd')
                pcd_nonground_minor = o3d.io.read_point_cloud(f'{out_folder}pcd_nonground_minor{SEQUENCE_NUM}_{cur_idx}.pcd')
                
                print("load data")
                kitti_labels_orig = {}
                with np.load(f'{out_folder}kitti_labels_preprocessed{SEQUENCE_NUM}_{cur_idx}.npz') as data :
                        kitti_labels_orig['instance_ground'] = data['instance_ground']
                        kitti_labels_orig['instance_nonground'] = data['instance_nonground']
                        kitti_labels_orig['seg_nonground'] = data['seg_nonground']
                        kitti_labels_orig['seg_ground'] = data['seg_ground']
        
                with np.load(f'{out_folder}all_poses_' + str(SEQUENCE_NUM) + '_' + str(cur_idx) + '.npz') as data:
                        all_poses = data['all_poses']
                        T_pcd = data['T_pcd']
                        first_position = T_pcd[:3, 3]
                        
                print("pose downsample")
                if os.path.exists(f'{out_folder}subsampled_data{SEQUENCE_NUM}_{cur_idx}.npz') == False : 
                        poses, positions, \
                        sampled_indices_local, sampled_indices_global = subsample_and_extract_positions(all_poses,ind_start=ind_start,sequence_num=SEQUENCE_NUM,out_folder=out_folder,cur_idx=cur_idx)
                
                with np.load(f'{out_folder}subsampled_data{SEQUENCE_NUM}_{cur_idx}.npz') as data:
                        poses = data['poses']
                        positions = data['positions']
                        sampled_indices_local = list(data['sampled_indices_local'])
                        sampled_indices_global = list(
                         data['sampled_indices_global'])
                        
                
                
                print("chunk downsample")
                pcd_nonground_chunks, pcd_ground_chunks,\
                pcd_nonground_chunks_major_downsampling, pcd_ground_chunks_major_downsampling, \
                indices,indices_ground, center_positions, \
                center_ids, chunk_bounds, kitti_labels = chunk_and_downsample_point_clouds(pcd_nonground_minor, pcd_ground_minor, T_pcd, positions, 
                                                                    first_position, sampled_indices_global, chunk_size=chunk_size, 
                                                                    overlap=overlap, major_voxel_size=major_voxel_size,kitti_labels=kitti_labels_orig)
                
                print("finished downsample")
                
                
                patchwise_indices = indices_per_patch(T_pcd, center_positions, positions, first_position, sampled_indices_global, chunk_size)
                out_data = []
                for sequence in range(len(center_ids))[:-1]:
                                try : 
                                        print("sequence",sequence)
                                        merged_chunk,file_name, pcd_chunk, pcd_chunk_ground,inliers, inliers_ground = ncuts_chunk(dataset,indices,pcd_nonground_chunks,pcd_ground_chunks,
                                                pcd_nonground_chunks_major_downsampling,
                                                pcd_nonground_minor,T_pcd,center_positions,center_ids,
                                                positions,first_position,sampled_indices_global,
                                                chunk_size=chunk_size,major_voxel_size=major_voxel_size,
                                                alpha=alpha,beta=beta,gamma=gamma,theta=theta,
                                                proximity_threshold=proximity_threshold,
                                                out_folder=out_folder_ncuts,ground_mode=False,sequence=sequence,
                                                patchwise_indices=patchwise_indices)
                                        
                                        #kitti_labels['ground']['panoptic'][sequence] = kitti_labels['ground']['panoptic'][sequence][inliers_ground]
                                        inst_labels = kitti_labels['ground']['instance'][sequence][inliers][inliers_ground]
                                        
                                        name = file_name.split('/')[-1]
                                        o3d.io.write_point_cloud(file_name, pcd_chunk + pcd_chunk_ground , write_ascii=False, compressed=False, print_progress=False)
                                        
                                        
                                        cur_name = name.split('.')[0]
                                        
                                        #import pdb; pdb.set_trace()
                                        #kitti_chunk = color_pcd_by_labels(pcd_chunk,kitti_labels['nonground']['panoptic'][sequence].reshape(-1,),
                                        #                        colors=colors,gt_labels=kitti_labels_orig['panoptic_nonground'])
                                        
                                        kitti_chunk_instance = color_pcd_by_labels(pcd_chunk,kitti_labels['nonground']['instance'][sequence].reshape(-1,),
                                                                colors=colors,gt_labels=kitti_labels_orig['instance_nonground'])
                                        
                                        gt_pcd = kitti_chunk_instance + pcd_chunk_ground
                                        pred_pcd = merged_chunk  + pcd_chunk_ground
                                        
                                        unique_colors, labels_ncuts = np.unique(np.asarray(pred_pcd.colors), axis=0, return_inverse=True)
                                        unique_colors, labels_kitti = np.unique(np.asarray(gt_pcd.colors),axis=0, return_inverse=True)
                                        
                                        pts = np.asarray(gt_pcd.points) 
                                        points,labels_ncuts,labels_kitti = downsample_chunk(pts,
                                                                                                labels_ncuts,labels_kitti)
                                        print("outut",data_store_folder + name.split('.')[0])
                                        np.savez(data_store_folder + name.split('.')[0] +  '.npz',pts=points,ncut_labels=labels_ncuts,
                                                kitti_labels=labels_kitti,cluster_labels=np.zeros_like(labels_ncuts))
                                        
                                        del points, labels_ncuts, labels_kitti 
                                        del pred_pcd, gt_pcd, kitti_chunk_instance, pcd_chunk, pcd_chunk_ground
                                        gc.collect()
                                except : 
                                        print("error",center_ids[sequence])
                                
                                #kitti_chunk_instance_ground = color_pcd_by_labels(pcd_chunk_ground,kitti_labels['ground']['instance'][sequence].reshape(-1,))
                                #o3d.io.write_point_cloud(out_dbscan + name, pcd_dbscan + pcd_chunk_ground, write_ascii=False, compressed=False, print_progress=False)
                                #o3d.io.write_point_cloud(out_kitti + name, kitti_chunk + pcd_chunk_ground, write_ascii=False, compressed=False, print_progress=False)
                                #o3d.io.write_point_cloud(out_kitti_instance + name, kitti_chunk_instance + pcd_chunk_ground, write_ascii=False, compressed=False, print_progress=False)
# Out:
# Sequence 1
# STORE FOLDER pcd_preprocessed/train_data/1/
# ind start 0
# ind end 200
# process poses
# PatchWorkpp::PatchWorkpp() - INITIALIZATION COMPLETE
# PointCloud with 6024244 points.
# load and downsample points
# (5712951, 3)
# (3628920, 3)
# (3628920, 3)
# (13801445, 3)
# done downsample
# write pcds
# PointCloud with 5712951 points.
# write labels
# load pcd
# load data
# pose downsample
# chunk downsample
# Downsampled from (10596, 3) to (589, 3) points (non-ground)
# Downsampled from (354153, 3) to (6753, 3) points (ground)
# Downsampled from (7479, 3) to (439, 3) points (non-ground)
# Downsampled from (367911, 3) to (6788, 3) points (ground)
# Downsampled from (5923, 3) to (354, 3) points (non-ground)
# Downsampled from (391172, 3) to (6465, 3) points (ground)
# Downsampled from (4543, 3) to (321, 3) points (non-ground)
# Downsampled from (410910, 3) to (6578, 3) points (ground)
# Downsampled from (4514, 3) to (313, 3) points (non-ground)
# Downsampled from (419553, 3) to (6634, 3) points (ground)
# Downsampled from (5212, 3) to (323, 3) points (non-ground)
# Downsampled from (434189, 3) to (6660, 3) points (ground)
# Downsampled from (6768, 3) to (400, 3) points (non-ground)
# Downsampled from (440552, 3) to (6643, 3) points (ground)
# Downsampled from (9248, 3) to (531, 3) points (non-ground)
# Downsampled from (446241, 3) to (6908, 3) points (ground)
# Downsampled from (8491, 3) to (475, 3) points (non-ground)
# Downsampled from (452587, 3) to (6726, 3) points (ground)
# Downsampled from (5675, 3) to (332, 3) points (non-ground)
# Downsampled from (454254, 3) to (6842, 3) points (ground)
# Downsampled from (5463, 3) to (297, 3) points (non-ground)
# Downsampled from (454418, 3) to (6726, 3) points (ground)
# Downsampled from (5268, 3) to (277, 3) points (non-ground)
# Downsampled from (454180, 3) to (6914, 3) points (ground)
# Downsampled from (9577, 3) to (371, 3) points (non-ground)
# Downsampled from (458008, 3) to (6910, 3) points (ground)
# Downsampled from (19715, 3) to (582, 3) points (non-ground)
# Downsampled from (462342, 3) to (6884, 3) points (ground)
# Downsampled from (38114, 3) to (948, 3) points (non-ground)
# Downsampled from (468933, 3) to (6972, 3) points (ground)
# Downsampled from (50931, 3) to (1124, 3) points (non-ground)
# Downsampled from (466745, 3) to (6834, 3) points (ground)
# Downsampled from (53575, 3) to (1198, 3) points (non-ground)
# Downsampled from (462625, 3) to (6678, 3) points (ground)
# Downsampled from (58229, 3) to (1199, 3) points (non-ground)
# Downsampled from (453467, 3) to (6515, 3) points (ground)
# Downsampled from (60348, 3) to (1210, 3) points (non-ground)
# Downsampled from (449210, 3) to (6508, 3) points (ground)
# Downsampled from (62722, 3) to (1221, 3) points (non-ground)
# Downsampled from (445150, 3) to (6482, 3) points (ground)
# Downsampled from (64061, 3) to (1236, 3) points (non-ground)
# Downsampled from (438431, 3) to (6378, 3) points (ground)
# Downsampled from (65343, 3) to (1252, 3) points (non-ground)
# Downsampled from (434942, 3) to (6284, 3) points (ground)
# Downsampled from (65918, 3) to (1266, 3) points (non-ground)
# Downsampled from (431609, 3) to (6254, 3) points (ground)
# Downsampled from (66376, 3) to (1268, 3) points (non-ground)
# Downsampled from (428159, 3) to (6193, 3) points (ground)
# Downsampled from (66291, 3) to (1266, 3) points (non-ground)
# Downsampled from (424764, 3) to (6160, 3) points (ground)
# Downsampled from (66580, 3) to (1263, 3) points (non-ground)
# Downsampled from (421142, 3) to (6160, 3) points (ground)
# Downsampled from (65730, 3) to (1245, 3) points (non-ground)
# Downsampled from (418466, 3) to (6149, 3) points (ground)
# Downsampled from (65576, 3) to (1230, 3) points (non-ground)
# Downsampled from (414800, 3) to (6179, 3) points (ground)
# Downsampled from (66190, 3) to (1244, 3) points (non-ground)
# Downsampled from (411547, 3) to (6224, 3) points (ground)
# Downsampled from (66488, 3) to (1241, 3) points (non-ground)
# Downsampled from (408474, 3) to (6175, 3) points (ground)
# Downsampled from (66640, 3) to (1239, 3) points (non-ground)
# Downsampled from (406140, 3) to (6139, 3) points (ground)
# Downsampled from (67246, 3) to (1265, 3) points (non-ground)
# Downsampled from (402059, 3) to (6224, 3) points (ground)
# Downsampled from (67428, 3) to (1251, 3) points (non-ground)
# Downsampled from (398224, 3) to (6186, 3) points (ground)
# Downsampled from (67386, 3) to (1259, 3) points (non-ground)
# Downsampled from (393768, 3) to (6179, 3) points (ground)
# Downsampled from (67170, 3) to (1257, 3) points (non-ground)
# Downsampled from (390570, 3) to (6127, 3) points (ground)
# Downsampled from (66280, 3) to (1237, 3) points (non-ground)
# Downsampled from (386921, 3) to (6207, 3) points (ground)
# Downsampled from (66073, 3) to (1229, 3) points (non-ground)
# Downsampled from (383575, 3) to (6013, 3) points (ground)
# Downsampled from (65456, 3) to (1242, 3) points (non-ground)
# Downsampled from (380940, 3) to (6056, 3) points (ground)
# Downsampled from (65478, 3) to (1237, 3) points (non-ground)
# Downsampled from (377201, 3) to (5984, 3) points (ground)
# Downsampled from (73048, 3) to (1382, 3) points (non-ground)
# Downsampled from (373754, 3) to (6003, 3) points (ground)
# Downsampled from (81748, 3) to (1612, 3) points (non-ground)
# Downsampled from (370512, 3) to (5997, 3) points (ground)
# Downsampled from (98434, 3) to (1858, 3) points (non-ground)
# Downsampled from (366962, 3) to (6014, 3) points (ground)
# Downsampled from (116523, 3) to (2222, 3) points (non-ground)
# Downsampled from (362746, 3) to (5862, 3) points (ground)
# Downsampled from (135011, 3) to (2561, 3) points (non-ground)
# Downsampled from (357837, 3) to (5941, 3) points (ground)
# Downsampled from (147005, 3) to (2761, 3) points (non-ground)
# Downsampled from (352657, 3) to (5836, 3) points (ground)
# Downsampled from (158323, 3) to (3006, 3) points (non-ground)
# Downsampled from (347665, 3) to (5796, 3) points (ground)
# Downsampled from (173403, 3) to (3259, 3) points (non-ground)
# Downsampled from (342932, 3) to (5836, 3) points (ground)
# Downsampled from (187815, 3) to (3476, 3) points (non-ground)
# Downsampled from (338855, 3) to (5670, 3) points (ground)
# Downsampled from (202095, 3) to (3835, 3) points (non-ground)
# Downsampled from (335161, 3) to (5668, 3) points (ground)
# Downsampled from (218178, 3) to (4248, 3) points (non-ground)
# Downsampled from (331171, 3) to (5580, 3) points (ground)
# Downsampled from (231449, 3) to (4463, 3) points (non-ground)
# Downsampled from (327489, 3) to (5627, 3) points (ground)
# Downsampled from (242514, 3) to (4743, 3) points (non-ground)
# Downsampled from (323941, 3) to (5484, 3) points (ground)
# Downsampled from (257784, 3) to (5016, 3) points (non-ground)
# Downsampled from (319895, 3) to (5461, 3) points (ground)
# Downsampled from (269362, 3) to (5303, 3) points (non-ground)
# Downsampled from (315452, 3) to (5462, 3) points (ground)
# Downsampled from (277370, 3) to (5516, 3) points (non-ground)
# Downsampled from (311536, 3) to (5333, 3) points (ground)
# Downsampled from (282120, 3) to (5618, 3) points (non-ground)
# Downsampled from (308330, 3) to (5308, 3) points (ground)
# Downsampled from (283207, 3) to (5659, 3) points (non-ground)
# Downsampled from (306461, 3) to (5247, 3) points (ground)
# Downsampled from (276131, 3) to (5583, 3) points (non-ground)
# Downsampled from (305694, 3) to (5305, 3) points (ground)
# Downsampled from (269505, 3) to (5486, 3) points (non-ground)
# Downsampled from (304272, 3) to (5278, 3) points (ground)
# Downsampled from (262865, 3) to (5397, 3) points (non-ground)
# Downsampled from (304598, 3) to (5291, 3) points (ground)
# Downsampled from (254879, 3) to (5233, 3) points (non-ground)
# Downsampled from (305396, 3) to (5359, 3) points (ground)
# Downsampled from (242854, 3) to (5060, 3) points (non-ground)
# Downsampled from (304701, 3) to (5379, 3) points (ground)
# Downsampled from (230904, 3) to (4964, 3) points (non-ground)
# Downsampled from (302809, 3) to (5388, 3) points (ground)
# Downsampled from (218629, 3) to (4717, 3) points (non-ground)
# Downsampled from (299484, 3) to (5391, 3) points (ground)
# Downsampled from (206221, 3) to (4472, 3) points (non-ground)
# Downsampled from (296466, 3) to (5387, 3) points (ground)
# Downsampled from (195989, 3) to (4263, 3) points (non-ground)
# Downsampled from (293769, 3) to (5494, 3) points (ground)
# Downsampled from (185054, 3) to (4019, 3) points (non-ground)
# Downsampled from (292079, 3) to (5454, 3) points (ground)
# Downsampled from (172394, 3) to (3738, 3) points (non-ground)
# Downsampled from (291209, 3) to (5496, 3) points (ground)
# Downsampled from (160963, 3) to (3487, 3) points (non-ground)
# Downsampled from (290171, 3) to (5412, 3) points (ground)
# Downsampled from (150969, 3) to (3182, 3) points (non-ground)
# Downsampled from (287943, 3) to (5370, 3) points (ground)
# Downsampled from (136481, 3) to (2844, 3) points (non-ground)
# Downsampled from (285822, 3) to (5324, 3) points (ground)
# Downsampled from (128302, 3) to (2656, 3) points (non-ground)
# Downsampled from (285292, 3) to (5393, 3) points (ground)
# Downsampled from (119457, 3) to (2457, 3) points (non-ground)
# Downsampled from (285032, 3) to (5495, 3) points (ground)
# Downsampled from (104474, 3) to (2097, 3) points (non-ground)
# Downsampled from (282707, 3) to (5551, 3) points (ground)
# Downsampled from (99634, 3) to (1965, 3) points (non-ground)
# Downsampled from (280727, 3) to (5581, 3) points (ground)
# Downsampled from (98209, 3) to (1844, 3) points (non-ground)
# Downsampled from (279371, 3) to (5631, 3) points (ground)
# Downsampled from (92383, 3) to (1721, 3) points (non-ground)
# Downsampled from (279593, 3) to (5703, 3) points (ground)
# Downsampled from (93266, 3) to (1800, 3) points (non-ground)
# Downsampled from (279127, 3) to (5722, 3) points (ground)
# Downsampled from (107495, 3) to (2081, 3) points (non-ground)
# Downsampled from (280674, 3) to (5793, 3) points (ground)
# Downsampled from (125650, 3) to (2397, 3) points (non-ground)
# Downsampled from (279160, 3) to (5815, 3) points (ground)
# Downsampled from (140516, 3) to (2748, 3) points (non-ground)
# Downsampled from (276734, 3) to (5783, 3) points (ground)
# Downsampled from (146594, 3) to (2939, 3) points (non-ground)
# Downsampled from (275325, 3) to (5761, 3) points (ground)
# Downsampled from (160297, 3) to (3238, 3) points (non-ground)
# Downsampled from (274976, 3) to (5774, 3) points (ground)
# Downsampled from (174744, 3) to (3459, 3) points (non-ground)
# Downsampled from (276346, 3) to (5734, 3) points (ground)
# Downsampled from (192931, 3) to (3664, 3) points (non-ground)
# Downsampled from (276232, 3) to (5735, 3) points (ground)
# Downsampled from (197315, 3) to (3837, 3) points (non-ground)
# Downsampled from (274111, 3) to (5782, 3) points (ground)
# Downsampled from (193488, 3) to (3892, 3) points (non-ground)
# Downsampled from (272813, 3) to (5781, 3) points (ground)
# Downsampled from (187477, 3) to (3846, 3) points (non-ground)
# Downsampled from (271928, 3) to (5747, 3) points (ground)
# Downsampled from (191474, 3) to (3983, 3) points (non-ground)
# Downsampled from (268199, 3) to (5627, 3) points (ground)
# Downsampled from (187525, 3) to (3936, 3) points (non-ground)
# Downsampled from (265738, 3) to (5516, 3) points (ground)
# Downsampled from (174955, 3) to (3755, 3) points (non-ground)
# Downsampled from (264002, 3) to (5410, 3) points (ground)
# Downsampled from (162473, 3) to (3527, 3) points (non-ground)
# Downsampled from (263796, 3) to (5349, 3) points (ground)
# Downsampled from (152826, 3) to (3380, 3) points (non-ground)
# Downsampled from (264024, 3) to (5391, 3) points (ground)
# Downsampled from (138198, 3) to (3028, 3) points (non-ground)
# Downsampled from (265200, 3) to (5431, 3) points (ground)
# Downsampled from (116956, 3) to (2680, 3) points (non-ground)
# Downsampled from (267738, 3) to (5520, 3) points (ground)
# Downsampled from (108089, 3) to (2362, 3) points (non-ground)
# Downsampled from (272469, 3) to (5667, 3) points (ground)
# Downsampled from (100317, 3) to (2226, 3) points (non-ground)
# Downsampled from (278129, 3) to (5773, 3) points (ground)
# Downsampled from (97456, 3) to (2039, 3) points (non-ground)
# Downsampled from (280557, 3) to (5746, 3) points (ground)
# Downsampled from (114939, 3) to (2313, 3) points (non-ground)
# Downsampled from (279335, 3) to (5846, 3) points (ground)
# Downsampled from (131070, 3) to (2581, 3) points (non-ground)
# Downsampled from (278557, 3) to (5855, 3) points (ground)
# Downsampled from (141968, 3) to (2799, 3) points (non-ground)
# Downsampled from (278664, 3) to (5802, 3) points (ground)
# Downsampled from (151612, 3) to (2881, 3) points (non-ground)
# Downsampled from (276004, 3) to (5715, 3) points (ground)
# Downsampled from (162516, 3) to (3188, 3) points (non-ground)
# Downsampled from (271804, 3) to (5588, 3) points (ground)
# Downsampled from (170453, 3) to (3386, 3) points (non-ground)
# Downsampled from (266304, 3) to (5529, 3) points (ground)
# Downsampled from (171845, 3) to (3383, 3) points (non-ground)
# Downsampled from (261606, 3) to (5454, 3) points (ground)
# Downsampled from (170523, 3) to (3266, 3) points (non-ground)
# Downsampled from (257755, 3) to (5418, 3) points (ground)
# Downsampled from (166210, 3) to (3197, 3) points (non-ground)
# Downsampled from (257024, 3) to (5418, 3) points (ground)
# Downsampled from (152759, 3) to (3029, 3) points (non-ground)
# Downsampled from (258530, 3) to (5438, 3) points (ground)
# Downsampled from (139338, 3) to (2793, 3) points (non-ground)
# Downsampled from (259572, 3) to (5547, 3) points (ground)
# Downsampled from (128927, 3) to (2563, 3) points (non-ground)
# Downsampled from (259315, 3) to (5706, 3) points (ground)
# Downsampled from (115052, 3) to (2204, 3) points (non-ground)
# Downsampled from (258874, 3) to (5748, 3) points (ground)
# Downsampled from (107186, 3) to (1983, 3) points (non-ground)
# Downsampled from (256652, 3) to (5753, 3) points (ground)
# Downsampled from (108661, 3) to (1993, 3) points (non-ground)
# Downsampled from (252220, 3) to (5666, 3) points (ground)
# Downsampled from (113854, 3) to (2025, 3) points (non-ground)
# Downsampled from (248999, 3) to (5613, 3) points (ground)
# Downsampled from (118963, 3) to (2054, 3) points (non-ground)
# Downsampled from (245526, 3) to (5546, 3) points (ground)
# Downsampled from (115017, 3) to (1889, 3) points (non-ground)
# Downsampled from (241638, 3) to (5636, 3) points (ground)
# Downsampled from (112030, 3) to (1812, 3) points (non-ground)
# Downsampled from (239365, 3) to (5601, 3) points (ground)
# Downsampled from (108088, 3) to (1707, 3) points (non-ground)
# Downsampled from (240184, 3) to (5669, 3) points (ground)
# Downsampled from (104515, 3) to (1645, 3) points (non-ground)
# Downsampled from (239315, 3) to (5651, 3) points (ground)
# Downsampled from (104012, 3) to (1574, 3) points (non-ground)
# Downsampled from (238083, 3) to (5524, 3) points (ground)
# Downsampled from (104852, 3) to (1545, 3) points (non-ground)
# Downsampled from (236458, 3) to (5548, 3) points (ground)
# Downsampled from (111072, 3) to (1743, 3) points (non-ground)
# Downsampled from (235409, 3) to (5582, 3) points (ground)
# Downsampled from (108043, 3) to (1690, 3) points (non-ground)
# Downsampled from (236668, 3) to (5642, 3) points (ground)
# Downsampled from (99123, 3) to (1584, 3) points (non-ground)
# Downsampled from (238096, 3) to (5636, 3) points (ground)
# Downsampled from (96718, 3) to (1539, 3) points (non-ground)
# Downsampled from (238409, 3) to (5642, 3) points (ground)
# Downsampled from (94712, 3) to (1506, 3) points (non-ground)
# Downsampled from (239969, 3) to (5671, 3) points (ground)
# Downsampled from (91045, 3) to (1507, 3) points (non-ground)
# Downsampled from (242442, 3) to (5611, 3) points (ground)
# Downsampled from (90552, 3) to (1533, 3) points (non-ground)
# Downsampled from (243738, 3) to (5701, 3) points (ground)
# Downsampled from (88975, 3) to (1529, 3) points (non-ground)
# Downsampled from (244592, 3) to (5686, 3) points (ground)
# Downsampled from (87653, 3) to (1490, 3) points (non-ground)
# Downsampled from (244684, 3) to (5688, 3) points (ground)
# Downsampled from (86470, 3) to (1502, 3) points (non-ground)
# Downsampled from (244579, 3) to (5677, 3) points (ground)
# Downsampled from (87577, 3) to (1505, 3) points (non-ground)
# Downsampled from (245049, 3) to (5742, 3) points (ground)
# Downsampled from (94931, 3) to (1824, 3) points (non-ground)
# Downsampled from (247469, 3) to (5723, 3) points (ground)
# Downsampled from (106633, 3) to (1968, 3) points (non-ground)
# Downsampled from (248250, 3) to (5774, 3) points (ground)
# Downsampled from (110482, 3) to (2084, 3) points (non-ground)
# Downsampled from (245645, 3) to (5664, 3) points (ground)
# Downsampled from (110333, 3) to (2070, 3) points (non-ground)
# Downsampled from (244287, 3) to (5650, 3) points (ground)
# Downsampled from (110483, 3) to (2007, 3) points (non-ground)
# Downsampled from (242065, 3) to (5684, 3) points (ground)
# Downsampled from (108680, 3) to (1959, 3) points (non-ground)
# Downsampled from (239188, 3) to (5659, 3) points (ground)
# Downsampled from (105917, 3) to (1846, 3) points (non-ground)
# Downsampled from (235692, 3) to (5681, 3) points (ground)
# Downsampled from (98528, 3) to (1647, 3) points (non-ground)
# Downsampled from (233830, 3) to (5562, 3) points (ground)
# Downsampled from (92800, 3) to (1535, 3) points (non-ground)
# Downsampled from (231219, 3) to (5600, 3) points (ground)
# Downsampled from (87791, 3) to (1375, 3) points (non-ground)
# Downsampled from (229677, 3) to (5549, 3) points (ground)
# Downsampled from (87355, 3) to (1405, 3) points (non-ground)
# Downsampled from (230457, 3) to (5544, 3) points (ground)
# Downsampled from (90734, 3) to (1579, 3) points (non-ground)
# Downsampled from (231650, 3) to (5638, 3) points (ground)
# Downsampled from (95284, 3) to (1766, 3) points (non-ground)
# Downsampled from (232758, 3) to (5626, 3) points (ground)
# Downsampled from (94444, 3) to (1762, 3) points (non-ground)
# Downsampled from (233349, 3) to (5652, 3) points (ground)
# Downsampled from (89266, 3) to (1593, 3) points (non-ground)
# Downsampled from (235412, 3) to (5631, 3) points (ground)
# Downsampled from (86670, 3) to (1445, 3) points (non-ground)
# Downsampled from (235022, 3) to (5653, 3) points (ground)
# Downsampled from (86619, 3) to (1419, 3) points (non-ground)
# Downsampled from (235089, 3) to (5545, 3) points (ground)
# Downsampled from (86749, 3) to (1417, 3) points (non-ground)
# Downsampled from (236132, 3) to (5597, 3) points (ground)
# Downsampled from (84824, 3) to (1391, 3) points (non-ground)
# Downsampled from (238263, 3) to (5579, 3) points (ground)
# Downsampled from (83721, 3) to (1366, 3) points (non-ground)
# Downsampled from (240706, 3) to (5578, 3) points (ground)
# Downsampled from (84655, 3) to (1395, 3) points (non-ground)
# Downsampled from (241392, 3) to (5616, 3) points (ground)
# Downsampled from (85172, 3) to (1398, 3) points (non-ground)
# Downsampled from (241348, 3) to (5571, 3) points (ground)
# Downsampled from (86104, 3) to (1405, 3) points (non-ground)
# Downsampled from (242873, 3) to (5574, 3) points (ground)
# Downsampled from (92222, 3) to (1547, 3) points (non-ground)
# Downsampled from (243810, 3) to (5632, 3) points (ground)
# Downsampled from (95541, 3) to (1677, 3) points (non-ground)
# Downsampled from (244076, 3) to (5669, 3) points (ground)
# Downsampled from (97277, 3) to (1787, 3) points (non-ground)
# Downsampled from (245596, 3) to (5697, 3) points (ground)
# Downsampled from (98284, 3) to (1886, 3) points (non-ground)
# Downsampled from (245825, 3) to (5656, 3) points (ground)
# Downsampled from (98225, 3) to (1878, 3) points (non-ground)
# Downsampled from (247251, 3) to (5674, 3) points (ground)
# Downsampled from (98484, 3) to (1998, 3) points (non-ground)
# Downsampled from (248506, 3) to (5665, 3) points (ground)
# Downsampled from (100302, 3) to (2061, 3) points (non-ground)
# Downsampled from (248300, 3) to (5659, 3) points (ground)
# Downsampled from (97729, 3) to (1943, 3) points (non-ground)
# Downsampled from (250478, 3) to (5669, 3) points (ground)
# Downsampled from (90725, 3) to (1759, 3) points (non-ground)
# Downsampled from (251566, 3) to (5639, 3) points (ground)
# Downsampled from (90579, 3) to (1748, 3) points (non-ground)
# Downsampled from (251224, 3) to (5769, 3) points (ground)
# Downsampled from (89753, 3) to (1734, 3) points (non-ground)
# Downsampled from (250979, 3) to (5806, 3) points (ground)
# Downsampled from (90754, 3) to (1805, 3) points (non-ground)
# Downsampled from (248343, 3) to (5817, 3) points (ground)
# Downsampled from (92154, 3) to (1851, 3) points (non-ground)
# Downsampled from (246120, 3) to (5756, 3) points (ground)
# Downsampled from (89840, 3) to (1658, 3) points (non-ground)
# Downsampled from (239449, 3) to (5597, 3) points (ground)
# Downsampled from (89964, 3) to (1641, 3) points (non-ground)
# Downsampled from (233857, 3) to (5570, 3) points (ground)
# Downsampled from (88991, 3) to (1600, 3) points (non-ground)
# Downsampled from (230344, 3) to (5577, 3) points (ground)
# Downsampled from (90825, 3) to (1570, 3) points (non-ground)
# Downsampled from (227077, 3) to (5561, 3) points (ground)
# Downsampled from (90348, 3) to (1529, 3) points (non-ground)
# Downsampled from (225211, 3) to (5499, 3) points (ground)
# Downsampled from (90393, 3) to (1508, 3) points (non-ground)
# Downsampled from (223270, 3) to (5520, 3) points (ground)
# Downsampled from (90370, 3) to (1388, 3) points (non-ground)
# Downsampled from (219987, 3) to (5476, 3) points (ground)
# Downsampled from (97428, 3) to (1629, 3) points (non-ground)
# Downsampled from (218610, 3) to (5465, 3) points (ground)
# Downsampled from (104981, 3) to (1891, 3) points (non-ground)
# Downsampled from (214440, 3) to (5311, 3) points (ground)
# Downsampled from (118300, 3) to (2377, 3) points (non-ground)
# Downsampled from (208907, 3) to (5249, 3) points (ground)
# Downsampled from (127222, 3) to (2724, 3) points (non-ground)
# Downsampled from (199479, 3) to (5019, 3) points (ground)
# Downsampled from (136020, 3) to (3203, 3) points (non-ground)
# Downsampled from (187984, 3) to (4951, 3) points (ground)
# Downsampled from (146565, 3) to (3658, 3) points (non-ground)
# Downsampled from (175701, 3) to (4717, 3) points (ground)
# Downsampled from (146385, 3) to (3752, 3) points (non-ground)
# Downsampled from (165655, 3) to (4638, 3) points (ground)
# Downsampled from (139347, 3) to (3690, 3) points (non-ground)
# Downsampled from (154733, 3) to (4596, 3) points (ground)
# Downsampled from (129711, 3) to (3625, 3) points (non-ground)
# Downsampled from (141603, 3) to (4509, 3) points (ground)
# Downsampled from (117465, 3) to (3686, 3) points (non-ground)
# Downsampled from (127625, 3) to (4428, 3) points (ground)
# Downsampled from (107005, 3) to (3719, 3) points (non-ground)
# Downsampled from (112556, 3) to (4284, 3) points (ground)
# finished downsample
# sequence 0
# Start of sequence 0
# 589 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 11 cut regions
# Ratio of points in top 3 groups: 0.6281833616298812
# outut pcd_preprocessed/train_data/1/000001
# sequence 1
# Start of sequence 1
# 439 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 8 cut regions
# Ratio of points in top 3 groups: 0.8519362186788155
# outut pcd_preprocessed/train_data/1/000002
# sequence 2
# Start of sequence 2
# 354 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.8192090395480226
# outut pcd_preprocessed/train_data/1/000004
# sequence 3
# Start of sequence 3
# 321 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.7320872274143302
# outut pcd_preprocessed/train_data/1/000006
# sequence 4
# Start of sequence 4
# 313 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 11 cut regions
# Ratio of points in top 3 groups: 0.6389776357827476
# outut pcd_preprocessed/train_data/1/000007
# sequence 5
# Start of sequence 5
# 323 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 15 cut regions
# Ratio of points in top 3 groups: 0.5758513931888545
# outut pcd_preprocessed/train_data/1/000009
# sequence 6
# Start of sequence 6
# 400 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 16 cut regions
# Ratio of points in top 3 groups: 0.5925
# outut pcd_preprocessed/train_data/1/000010
# sequence 7
# Start of sequence 7
# 531 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 12 cut regions
# Ratio of points in top 3 groups: 0.7966101694915254
# outut pcd_preprocessed/train_data/1/000012
# sequence 8
# Start of sequence 8
# 475 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 12 cut regions
# Ratio of points in top 3 groups: 0.7347368421052631
# outut pcd_preprocessed/train_data/1/000015
# sequence 9
# Start of sequence 9
# 332 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.8433734939759037
# outut pcd_preprocessed/train_data/1/000017
# sequence 10
# Start of sequence 10
# 297 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.8215488215488216
# outut pcd_preprocessed/train_data/1/000018
# sequence 11
# Start of sequence 11
# 277 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 8 cut regions
# Ratio of points in top 3 groups: 0.8736462093862816
# outut pcd_preprocessed/train_data/1/000020
# sequence 12
# Start of sequence 12
# 371 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.8436657681940701
# outut pcd_preprocessed/train_data/1/000022
# sequence 13
# Start of sequence 13
# 582 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.8762886597938144
# outut pcd_preprocessed/train_data/1/000023
# sequence 14
# Start of sequence 14
# 948 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 12 cut regions
# Ratio of points in top 3 groups: 0.8491561181434599
# outut pcd_preprocessed/train_data/1/000025
# sequence 15
# Start of sequence 15
# 1124 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.9421708185053381
# outut pcd_preprocessed/train_data/1/000027
# sequence 16
# Start of sequence 16
# 1198 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.9106844741235393
# outut pcd_preprocessed/train_data/1/000028
# sequence 17
# Start of sequence 17
# 1199 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.9641367806505421
# outut pcd_preprocessed/train_data/1/000031
# sequence 18
# Start of sequence 18
# 1210 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.9454545454545454
# outut pcd_preprocessed/train_data/1/000032
# sequence 19
# Start of sequence 19
# 1221 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.9696969696969697
# outut pcd_preprocessed/train_data/1/000033
# sequence 20
# Start of sequence 20
# 1236 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.9692556634304207
# outut pcd_preprocessed/train_data/1/000034
# sequence 21
# Start of sequence 21
# 1252 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.9688498402555911
# outut pcd_preprocessed/train_data/1/000035
# sequence 22
# Start of sequence 22
# 1266 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.9652448657187994
# outut pcd_preprocessed/train_data/1/000036
# sequence 23
# Start of sequence 23
# 1268 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 11 cut regions
# Ratio of points in top 3 groups: 0.9605678233438486
# outut pcd_preprocessed/train_data/1/000037
# sequence 24
# Start of sequence 24
# 1266 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.9676145339652449
# outut pcd_preprocessed/train_data/1/000038
# sequence 25
# Start of sequence 25
# 1263 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.9469517022961204
# outut pcd_preprocessed/train_data/1/000039
# sequence 26
# Start of sequence 26
# 1245 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 8 cut regions
# Ratio of points in top 3 groups: 0.976706827309237
# outut pcd_preprocessed/train_data/1/000040
# sequence 27
# Start of sequence 27
# 1230 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 8 cut regions
# Ratio of points in top 3 groups: 0.9821138211382113
# outut pcd_preprocessed/train_data/1/000041
# sequence 28
# Start of sequence 28
# 1244 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.9807073954983923
# outut pcd_preprocessed/train_data/1/000042
# sequence 29
# Start of sequence 29
# 1241 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.9798549556809025
# outut pcd_preprocessed/train_data/1/000043
# sequence 30
# Start of sequence 30
# 1239 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.9814366424535916
# outut pcd_preprocessed/train_data/1/000044
# sequence 31
# Start of sequence 31
# 1265 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 11 cut regions
# Ratio of points in top 3 groups: 0.9723320158102767
# outut pcd_preprocessed/train_data/1/000045
# sequence 32
# Start of sequence 32
# 1251 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.9752198241406874
# outut pcd_preprocessed/train_data/1/000046
# sequence 33
# Start of sequence 33
# 1259 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 11 cut regions
# Ratio of points in top 3 groups: 0.9682287529785544
# outut pcd_preprocessed/train_data/1/000047
# sequence 34
# Start of sequence 34
# 1257 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.9737470167064439
# outut pcd_preprocessed/train_data/1/000048
# sequence 35
# Start of sequence 35
# 1237 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.9749393694421988
# outut pcd_preprocessed/train_data/1/000049
# sequence 36
# Start of sequence 36
# 1229 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 7 cut regions
# Ratio of points in top 3 groups: 0.9812855980471928
# outut pcd_preprocessed/train_data/1/000050
# sequence 37
# Start of sequence 37
# 1242 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 12 cut regions
# Ratio of points in top 3 groups: 0.9734299516908212
# outut pcd_preprocessed/train_data/1/000051
# sequence 38
# Start of sequence 38
# 1237 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 12 cut regions
# Ratio of points in top 3 groups: 0.9652384801940178
# outut pcd_preprocessed/train_data/1/000052
# sequence 39
# Start of sequence 39
# 1382 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 7 cut regions
# Ratio of points in top 3 groups: 0.9826338639652678
# outut pcd_preprocessed/train_data/1/000053
# sequence 40
# Start of sequence 40
# 1612 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.8163771712158809
# outut pcd_preprocessed/train_data/1/000054
# sequence 41
# Start of sequence 41
# 1858 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 5 cut regions
# Ratio of points in top 3 groups: 0.9924650161463939
# outut pcd_preprocessed/train_data/1/000055
# sequence 42
# Start of sequence 42
# 2222 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 5 cut regions
# Ratio of points in top 3 groups: 0.9914491449144914
# outut pcd_preprocessed/train_data/1/000056
# sequence 43
# Start of sequence 43
# 2561 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 7 cut regions
# Ratio of points in top 3 groups: 0.9012104646622413
# outut pcd_preprocessed/train_data/1/000057
# sequence 44
# Start of sequence 44
# 2761 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 7 cut regions
# Ratio of points in top 3 groups: 0.8797537124230351
# outut pcd_preprocessed/train_data/1/000058
# sequence 45
# Start of sequence 45
# 3006 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 6 cut regions
# Ratio of points in top 3 groups: 0.874251497005988
# outut pcd_preprocessed/train_data/1/000059
# sequence 46
# Start of sequence 46
# 3259 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 6 cut regions
# Ratio of points in top 3 groups: 0.8922982509972384
# outut pcd_preprocessed/train_data/1/000060
# sequence 47
# Start of sequence 47
# 3476 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 5 cut regions
# Ratio of points in top 3 groups: 0.9959723820483314
# outut pcd_preprocessed/train_data/1/000061
# sequence 48
# Start of sequence 48
# 3835 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 6 cut regions
# Ratio of points in top 3 groups: 0.9392438070404172
# outut pcd_preprocessed/train_data/1/000062
# sequence 49
# Start of sequence 49
# 4248 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 8 cut regions
# Ratio of points in top 3 groups: 0.8848870056497176
# outut pcd_preprocessed/train_data/1/000063
# sequence 50
# Start of sequence 50
# 4463 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.9045485099708717
# outut pcd_preprocessed/train_data/1/000064
# sequence 51
# Start of sequence 51
# 4743 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 7 cut regions
# Ratio of points in top 3 groups: 0.8888888888888888
# outut pcd_preprocessed/train_data/1/000065
# sequence 52
# Start of sequence 52
# 5016 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 6 cut regions
# Ratio of points in top 3 groups: 0.8881578947368421
# outut pcd_preprocessed/train_data/1/000066
# sequence 53
# Start of sequence 53
# 5303 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 8 cut regions
# Ratio of points in top 3 groups: 0.8813878936451065
# outut pcd_preprocessed/train_data/1/000067
# sequence 54
# Start of sequence 54
# 5516 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 7 cut regions
# Ratio of points in top 3 groups: 0.8866932559825961
# outut pcd_preprocessed/train_data/1/000068
# sequence 55
# Start of sequence 55
# 5618 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 7 cut regions
# Ratio of points in top 3 groups: 0.8965824136703453
# outut pcd_preprocessed/train_data/1/000069
# sequence 56
# Start of sequence 56
# 5659 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.8983919420392296
# outut pcd_preprocessed/train_data/1/000070
# sequence 57
# Start of sequence 57
# 5583 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 8 cut regions
# Ratio of points in top 3 groups: 0.7941966684578183
# outut pcd_preprocessed/train_data/1/000071
# sequence 58
# Start of sequence 58
# 5486 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.7903755012759752
# outut pcd_preprocessed/train_data/1/000072
# sequence 59
# Start of sequence 59
# 5397 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.896053362979433
# outut pcd_preprocessed/train_data/1/000073
# sequence 60
# Start of sequence 60
# 5233 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 12 cut regions
# Ratio of points in top 3 groups: 0.893942289317791
# outut pcd_preprocessed/train_data/1/000074
# sequence 61
# Start of sequence 61
# 5060 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.9007905138339921
# outut pcd_preprocessed/train_data/1/000075
# sequence 62
# Start of sequence 62
# 4964 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 12 cut regions
# Ratio of points in top 3 groups: 0.879129734085415
# outut pcd_preprocessed/train_data/1/000076
# sequence 63
# Start of sequence 63
# 4717 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.8778884884460462
# outut pcd_preprocessed/train_data/1/000077
# sequence 64
# Start of sequence 64
# 4472 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 8 cut regions
# Ratio of points in top 3 groups: 0.9921735241502684
# outut pcd_preprocessed/train_data/1/000078
# sequence 65
# Start of sequence 65
# 4263 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 6 cut regions
# Ratio of points in top 3 groups: 0.995777621393385
# outut pcd_preprocessed/train_data/1/000079
# sequence 66
# Start of sequence 66
# 4019 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 7 cut regions
# Ratio of points in top 3 groups: 0.8186115949241105
# outut pcd_preprocessed/train_data/1/000080
# sequence 67
# Start of sequence 67
# 3738 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 6 cut regions
# Ratio of points in top 3 groups: 0.8560727661851257
# outut pcd_preprocessed/train_data/1/000081
# sequence 68
# Start of sequence 68
# 3487 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 5 cut regions
# Ratio of points in top 3 groups: 0.9942644106681962
# outut pcd_preprocessed/train_data/1/000082
# sequence 69
# Start of sequence 69
# 3182 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 5 cut regions
# Ratio of points in top 3 groups: 0.9937146448774355
# outut pcd_preprocessed/train_data/1/000083
# sequence 70
# Start of sequence 70
# 2844 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 6 cut regions
# Ratio of points in top 3 groups: 0.9683544303797469
# outut pcd_preprocessed/train_data/1/000084
# sequence 71
# Start of sequence 71
# 2656 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 5 cut regions
# Ratio of points in top 3 groups: 0.9917168674698795
# outut pcd_preprocessed/train_data/1/000085
# sequence 72
# Start of sequence 72
# 2457 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 7 cut regions
# Ratio of points in top 3 groups: 0.9792429792429792
# outut pcd_preprocessed/train_data/1/000086
# sequence 73
# Start of sequence 73
# 2097 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.9470672389127325
# outut pcd_preprocessed/train_data/1/000087
# sequence 74
# Start of sequence 74
# 1965 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 11 cut regions
# Ratio of points in top 3 groups: 0.9027989821882951
# outut pcd_preprocessed/train_data/1/000088
# sequence 75
# Start of sequence 75
# 1844 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.8823210412147505
# outut pcd_preprocessed/train_data/1/000089
# sequence 76
# Start of sequence 76
# 1721 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 8 cut regions
# Ratio of points in top 3 groups: 0.8512492736780941
# outut pcd_preprocessed/train_data/1/000090
# sequence 77
# Start of sequence 77
# 1800 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 8 cut regions
# Ratio of points in top 3 groups: 0.9033333333333333
# outut pcd_preprocessed/train_data/1/000091
# sequence 78
# Start of sequence 78
# 2081 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.8423834694858241
# outut pcd_preprocessed/train_data/1/000092
# sequence 79
# Start of sequence 79
# 2397 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 8 cut regions
# Ratio of points in top 3 groups: 0.7959949937421777
# outut pcd_preprocessed/train_data/1/000093
# sequence 80
# Start of sequence 80
# 2748 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 5 cut regions
# Ratio of points in top 3 groups: 0.9894468704512372
# outut pcd_preprocessed/train_data/1/000094
# sequence 81
# Start of sequence 81
# 2939 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 7 cut regions
# Ratio of points in top 3 groups: 0.9639333106498809
# outut pcd_preprocessed/train_data/1/000095
# sequence 82
# Start of sequence 82
# 3238 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.8687461395923409
# outut pcd_preprocessed/train_data/1/000096
# sequence 83
# Start of sequence 83
# 3459 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 12 cut regions
# Ratio of points in top 3 groups: 0.7571552471812663
# outut pcd_preprocessed/train_data/1/000097
# sequence 84
# Start of sequence 84
# 3664 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.5971615720524017
# outut pcd_preprocessed/train_data/1/000098
# sequence 85
# Start of sequence 85
# 3837 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 10 cut regions
# Ratio of points in top 3 groups: 0.7339066979410999
# outut pcd_preprocessed/train_data/1/000099
# sequence 86
# Start of sequence 86
# 3892 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.7201952723535457
# outut pcd_preprocessed/train_data/1/000100
# sequence 87
# Start of sequence 87
# 3846 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.7389495579823193
# outut pcd_preprocessed/train_data/1/000101
# sequence 88
# Start of sequence 88
# 3983 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 11 cut regions
# Ratio of points in top 3 groups: 0.8036655787095155
# outut pcd_preprocessed/train_data/1/000102
# sequence 89
# Start of sequence 89
# 3936 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 9 cut regions
# Ratio of points in top 3 groups: 0.944359756097561
# outut pcd_preprocessed/train_data/1/000103
# sequence 90
# Start of sequence 90
# 3755 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 11 cut regions
# Ratio of points in top 3 groups: 0.8793608521970706
# outut pcd_preprocessed/train_data/1/000104
# sequence 91
# Start of sequence 91
# 3527 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 12 cut regions
# Ratio of points in top 3 groups: 0.8471789055854834
# outut pcd_preprocessed/train_data/1/000105
# sequence 92
# Start of sequence 92
# 3380 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 12 cut regions
# Ratio of points in top 3 groups: 0.863905325443787
# outut pcd_preprocessed/train_data/1/000106
# sequence 93
# Start of sequence 93
# 3028 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 11 cut regions
# Ratio of points in top 3 groups: 0.8236459709379128
# outut pcd_preprocessed/train_data/1/000107
# sequence 94
# Start of sequence 94
# 2680 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 13 cut regions
# Ratio of points in top 3 groups: 0.8026119402985075
# outut pcd_preprocessed/train_data/1/000108
# sequence 95
# Start of sequence 95
# ...
# outut pcd_preprocessed/train_data/2/002075
# sequence 50
# Start of sequence 50
# 6199 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 26 cut regions
# Ratio of points in top 3 groups: 0.5329891918051298
# outut pcd_preprocessed/train_data/2/002076
# sequence 51
# Start of sequence 51
# 6118 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 31 cut regions
# Ratio of points in top 3 groups: 0.5849950964367441
# outut pcd_preprocessed/train_data/2/002077
# sequence 52
# Start of sequence 52
# 5945 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 28 cut regions
# Ratio of points in top 3 groups: 0.4590412111017662
# outut pcd_preprocessed/train_data/2/002078
# sequence 53
# Start of sequence 53
# 5809 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 32 cut regions
# Ratio of points in top 3 groups: 0.4128077121707695
# outut pcd_preprocessed/train_data/2/002079
# sequence 54
# Start of sequence 54
# 5661 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 26 cut regions
# Ratio of points in top 3 groups: 0.5405405405405406
# outut pcd_preprocessed/train_data/2/002080
# sequence 55
# Start of sequence 55
# 5772 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 27 cut regions
# Ratio of points in top 3 groups: 0.5630630630630631
# outut pcd_preprocessed/train_data/2/002081
# sequence 56
# Start of sequence 56
# 5914 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 27 cut regions
# Ratio of points in top 3 groups: 0.4873182279337166
# outut pcd_preprocessed/train_data/2/002082
# sequence 57
# Start of sequence 57
# 6076 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 25 cut regions
# Ratio of points in top 3 groups: 0.5477287689269256
# outut pcd_preprocessed/train_data/2/002083
# sequence 58
# Start of sequence 58
# 6229 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 34 cut regions
# Ratio of points in top 3 groups: 0.5259271151067587
# outut pcd_preprocessed/train_data/2/002084
# sequence 59
# Start of sequence 59
# 6478 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 29 cut regions
# Ratio of points in top 3 groups: 0.5092621179376351
# outut pcd_preprocessed/train_data/2/002085
# sequence 60
# Start of sequence 60
# 6826 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 34 cut regions
# Ratio of points in top 3 groups: 0.4623498388514503
# outut pcd_preprocessed/train_data/2/002086
# sequence 61
# Start of sequence 61
# 7254 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 31 cut regions
# Ratio of points in top 3 groups: 0.460573476702509
# outut pcd_preprocessed/train_data/2/002087
# sequence 62
# Start of sequence 62
# 7384 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 28 cut regions
# Ratio of points in top 3 groups: 0.5299295774647887
# outut pcd_preprocessed/train_data/2/002088
# sequence 63
# Start of sequence 63
# 7415 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 32 cut regions
# Ratio of points in top 3 groups: 0.5637221847606204
# outut pcd_preprocessed/train_data/2/002089
# sequence 64
# Start of sequence 64
# 7307 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 29 cut regions
# Ratio of points in top 3 groups: 0.5553578760093062
# outut pcd_preprocessed/train_data/2/002090
# sequence 65
# Start of sequence 65
# 7288 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 28 cut regions
# Ratio of points in top 3 groups: 0.5894621295279913
# outut pcd_preprocessed/train_data/2/002091
# sequence 66
# Start of sequence 66
# 7535 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 30 cut regions
# Ratio of points in top 3 groups: 0.6463171864631718
# outut pcd_preprocessed/train_data/2/002092
# sequence 67
# Start of sequence 67
# 7748 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 30 cut regions
# Ratio of points in top 3 groups: 0.6726897263810016
# outut pcd_preprocessed/train_data/2/002093
# sequence 68
# Start of sequence 68
# 7946 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 36 cut regions
# Ratio of points in top 3 groups: 0.6964510445507174
# outut pcd_preprocessed/train_data/2/002094
# sequence 69
# Start of sequence 69
# 8051 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 34 cut regions
# Ratio of points in top 3 groups: 0.5107440069556577
# outut pcd_preprocessed/train_data/2/002095
# sequence 70
# Start of sequence 70
# 8112 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 36 cut regions
# Ratio of points in top 3 groups: 0.48200197238658776
# outut pcd_preprocessed/train_data/2/002096
# sequence 71
# Start of sequence 71
# 7870 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 36 cut regions
# Ratio of points in top 3 groups: 0.5725540025412961
# outut pcd_preprocessed/train_data/2/002097
# sequence 72
# Start of sequence 72
# 7840 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 29 cut regions
# Ratio of points in top 3 groups: 0.5783163265306123
# outut pcd_preprocessed/train_data/2/002098
# sequence 73
# Start of sequence 73
# 7572 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 31 cut regions
# Ratio of points in top 3 groups: 0.5274696249339672
# outut pcd_preprocessed/train_data/2/002099
# sequence 74
# Start of sequence 74
# 7375 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 33 cut regions
# Ratio of points in top 3 groups: 0.5113220338983051
# outut pcd_preprocessed/train_data/2/002100
# sequence 75
# Start of sequence 75
# 7103 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 36 cut regions
# Ratio of points in top 3 groups: 0.3709700126707025
# outut pcd_preprocessed/train_data/2/002101
# sequence 76
# Start of sequence 76
# 6804 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 32 cut regions
# Ratio of points in top 3 groups: 0.43415637860082307
# outut pcd_preprocessed/train_data/2/002102
# sequence 77
# Start of sequence 77
# 6144 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 34 cut regions
# Ratio of points in top 3 groups: 0.5048828125
# outut pcd_preprocessed/train_data/2/002103
# sequence 78
# Start of sequence 78
# 5912 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 37 cut regions
# Ratio of points in top 3 groups: 0.3668809201623816
# outut pcd_preprocessed/train_data/2/002104
# sequence 79
# Start of sequence 79
# 5606 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 35 cut regions
# Ratio of points in top 3 groups: 0.3813770959686051
# outut pcd_preprocessed/train_data/2/002105
# sequence 80
# Start of sequence 80
# 5031 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 35 cut regions
# Ratio of points in top 3 groups: 0.4400715563506261
# outut pcd_preprocessed/train_data/2/002106
# sequence 81
# Start of sequence 81
# 4568 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 33 cut regions
# Ratio of points in top 3 groups: 0.3480735551663748
# outut pcd_preprocessed/train_data/2/002107
# sequence 82
# Start of sequence 82
# 4251 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 31 cut regions
# Ratio of points in top 3 groups: 0.35615149376617267
# outut pcd_preprocessed/train_data/2/002108
# sequence 83
# Start of sequence 83
# 4003 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 26 cut regions
# Ratio of points in top 3 groups: 0.36097926555083687
# outut pcd_preprocessed/train_data/2/002109
# sequence 84
# Start of sequence 84
# 3699 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 26 cut regions
# Ratio of points in top 3 groups: 0.36550419032170856
# outut pcd_preprocessed/train_data/2/002110
# sequence 85
# Start of sequence 85
# 3884 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 25 cut regions
# Ratio of points in top 3 groups: 0.4140061791967044
# outut pcd_preprocessed/train_data/2/002111
# sequence 86
# Start of sequence 86
# 4240 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 25 cut regions
# Ratio of points in top 3 groups: 0.3594339622641509
# outut pcd_preprocessed/train_data/2/002112
# sequence 87
# Start of sequence 87
# 4311 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 24 cut regions
# Ratio of points in top 3 groups: 0.32799814428206914
# outut pcd_preprocessed/train_data/2/002113
# sequence 88
# Start of sequence 88
# 4234 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 21 cut regions
# Ratio of points in top 3 groups: 0.4357581483230987
# outut pcd_preprocessed/train_data/2/002114
# sequence 89
# Start of sequence 89
# 4295 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 19 cut regions
# Ratio of points in top 3 groups: 0.4391152502910361
# outut pcd_preprocessed/train_data/2/002115
# sequence 90
# Start of sequence 90
# 4784 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 18 cut regions
# Ratio of points in top 3 groups: 0.40259197324414714
# outut pcd_preprocessed/train_data/2/002116
# sequence 91
# Start of sequence 91
# 4860 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 21 cut regions
# Ratio of points in top 3 groups: 0.3911522633744856
# outut pcd_preprocessed/train_data/2/002117
# sequence 92
# Start of sequence 92
# 4788 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 24 cut regions
# Ratio of points in top 3 groups: 0.3767752715121136
# outut pcd_preprocessed/train_data/2/002118
# sequence 93
# Start of sequence 93
# 4897 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 22 cut regions
# Ratio of points in top 3 groups: 0.42393302021645907
# outut pcd_preprocessed/train_data/2/002119
# sequence 94
# Start of sequence 94
# 4833 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 19 cut regions
# Ratio of points in top 3 groups: 0.40554521001448374
# outut pcd_preprocessed/train_data/2/002120
# sequence 95
# Start of sequence 95
# 5062 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 20 cut regions
# Ratio of points in top 3 groups: 0.372580007902015
# outut pcd_preprocessed/train_data/2/002121
# sequence 96
# Start of sequence 96
# 5104 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 17 cut regions
# Ratio of points in top 3 groups: 0.36990595611285265
# outut pcd_preprocessed/train_data/2/002122
# sequence 97
# Start of sequence 97
# 5039 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 24 cut regions
# Ratio of points in top 3 groups: 0.3595951577693987
# outut pcd_preprocessed/train_data/2/002123
# sequence 98
# Start of sequence 98
# 5082 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 21 cut regions
# Ratio of points in top 3 groups: 0.3431719795356159
# outut pcd_preprocessed/train_data/2/002124
# sequence 99
# Start of sequence 99
# 5024 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 22 cut regions
# Ratio of points in top 3 groups: 0.3684315286624204
# outut pcd_preprocessed/train_data/2/002125
# sequence 100
# Start of sequence 100
# 4980 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 30 cut regions
# Ratio of points in top 3 groups: 0.4126506024096386
# outut pcd_preprocessed/train_data/2/002126
# sequence 101
# Start of sequence 101
# 4876 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 24 cut regions
# Ratio of points in top 3 groups: 0.31009023789991796
# outut pcd_preprocessed/train_data/2/002127
# sequence 102
# Start of sequence 102
# 4748 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 19 cut regions
# Ratio of points in top 3 groups: 0.42165122156697554
# outut pcd_preprocessed/train_data/2/002128
# sequence 103
# Start of sequence 103
# 4786 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 17 cut regions
# Ratio of points in top 3 groups: 0.43877977434183035
# outut pcd_preprocessed/train_data/2/002129
# sequence 104
# Start of sequence 104
# 4968 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 25 cut regions
# Ratio of points in top 3 groups: 0.339170692431562
# outut pcd_preprocessed/train_data/2/002130
# sequence 105
# Start of sequence 105
# 4770 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 28 cut regions
# Ratio of points in top 3 groups: 0.3048218029350105
# outut pcd_preprocessed/train_data/2/002131
# sequence 106
# Start of sequence 106
# 5032 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 26 cut regions
# Ratio of points in top 3 groups: 0.24960254372019078
# outut pcd_preprocessed/train_data/2/002132
# sequence 107
# Start of sequence 107
# 5279 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 26 cut regions
# Ratio of points in top 3 groups: 0.2165182799772684
# outut pcd_preprocessed/train_data/2/002133
# sequence 108
# Start of sequence 108
# 5506 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 34 cut regions
# Ratio of points in top 3 groups: 0.22557210316018889
# outut pcd_preprocessed/train_data/2/002134
# sequence 109
# Start of sequence 109
# 5421 points in downsampled chunk (major)

# %%
o3d.io.write_point_cloud(f'{out_folder}pcd_ground_minor{SEQUENCE_NUM}_{cur_idx}.pcd', pcd_ground_minor, write_ascii=False, compressed=False, print_progress=True)
# Out:
# True

# %%
def divide_indices_into_chunks(max_index, chunk_size=1000):
    chunks = []
    for start in range(0, max_index, chunk_size):
        end = min(start + chunk_size, max_index)
        chunks.append((start, end))
    return chunks

# Example usage
max_index = 4500  # Example maximum index
chunks = divide_indices_into_chunks(max_index)

for chunk in chunks:
    print(chunk)
# Out:
# (0, 1000)
# (1000, 2000)
# (2000, 3000)
# (3000, 4000)
# (4000, 4500)

# %% [markdown]
# Now we aggregate a large point cloud based on (ind_start, ind_end)

# %%
'''
pcd_new = o3d.geometry.PointCloud()
pts_num = 1000000
pcd_new.points = o3d.utility.Vector3dVector(np.asarray(pcd_nonground_minor.points)[:pts_num])

map_labelled = color_pcd_by_labels(pcd_new,\
                kitti_labels['panoptic_nonground'][:pts_num].reshape(-1,1))

o3d.visualization.draw_geometries([map_labelled])
#o3d.io.write_point_cloud('labelled_map07.pcd',map_labelled)
'''
# Out:
# "\npcd_new = o3d.geometry.PointCloud()\npts_num = 1000000\npcd_new.points = o3d.utility.Vector3dVector(np.asarray(pcd_nonground_minor.points)[:pts_num])\n\nmap_labelled = color_pcd_by_labels(pcd_new,                kitti_labels['panoptic_nonground'][:pts_num].reshape(-1,1))\n\no3d.visualization.draw_geometries([map_labelled])\n#o3d.io.write_point_cloud('labelled_map07.pcd',map_labelled)\n"

# %% [markdown]
# Now we subsample the poses based on a voxel_size

# %% [markdown]
# Now we can split the point cloud into chunks based on a tbd chunk_size

# %%
unique_colors, labels_ncuts = np.unique(np.asarray(merge.colors), axis=0, return_inverse=True)
unique_colors, labels_dbscan = np.unique(np.asarray(merge_dbscan.colors), axis=0, return_inverse=True)
unique_colors, labels_kitti = np.unique(np.asarray(merge_kitti_instance.colors),axis=0, return_inverse=True)



new_ncuts_labels = remove_semantics(labels_kitti,labels_ncuts)
new_dbscan_labels = remove_semantics(labels_kitti,labels_dbscan)


'''
metrics_ncuts = Metrics(name='ncuts')
metrics_dbscan = Metrics(name='dbscan')
metrics_test = Metrics(name='test')

metrics_ncuts.update_stats(new_ncuts_labels,labels_kitti)

metrics_dbscan.update_stats(new_dbscan_labels,labels_kitti)

metrics_dbscan.compute_all_aps()
metrics_ncuts.compute_all_aps()
'''
#merge_vis = color_pcd_by_labels(merge,labels)
#o3d.visualization.draw_geometries([merge_vis])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/cedric/unsup_3d_instances/point-to-pixel-mapping/example_dataset_generation_out_preprocess_train.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/home/cedric/unsup_3d_instances/point-to-pixel-mapping/example_dataset_generation_out_preprocess_train.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> unique_colors, labels_ncuts = np.unique(np.asarray(merge.colors), axis=0, return_inverse=True)
#       <a href='vscode-notebook-cell:/home/cedric/unsup_3d_instances/point-to-pixel-mapping/example_dataset_generation_out_preprocess_train.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> unique_colors, labels_dbscan = np.unique(np.asarray(merge_dbscan.colors), axis=0, return_inverse=True)
#       <a href='vscode-notebook-cell:/home/cedric/unsup_3d_instances/point-to-pixel-mapping/example_dataset_generation_out_preprocess_train.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> unique_colors, labels_kitti = np.unique(np.asarray(merge_kitti_instance.colors),axis=0, return_inverse=True)
#
# NameError: name 'merge' is not defined

# %%
new_kitti_pcd = color_pcd_by_labels(merge_dbscan,new_ncuts_labels)
o3d.io.write_point_cloud(out_folder + "ncuts_instances_tarl.pcd",new_kitti_pcd, write_ascii=False, compressed=False, print_progress=False)
#new_dbscan_pcd = color_pcd_by_labels(merge_dbscan,new_dbscan_labels)
#o3d.io.write_point_cloud(out_folder + "dbscan_instances.pcd",new_dbscan_pcd, write_ascii=False, compressed=False, print_progress=False)
# Out:
# True

# %%
metrics_ncuts = Metrics(name='ncuts')
metrics_dbscan = Metrics(name='dbscan')
metrics_test = Metrics(name='test')

metrics_ncuts.update_stats(new_ncuts_labels,labels_kitti)
#metrics_dbscan.update_stats(new_dbscan_labels,labels_kitti)
metrics_ncuts.compute_all_aps()
#metrics_dbscan.compute_all_aps()

# %%
o3d.visualization.draw_geometries([new_kitti_pcd])
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display

# %%
DATASET_PATH = os.path.join('/Users/cedric/Datasets/semantic_kitti/')
SEQUENCE_NUM = 7

dataset = create_kitti_odometry_dataset(DATASET_PATH,SEQUENCE_NUM,ncuts_mode=False)

# %%
from open3d.pipelines import registration
import numpy as np 
merge.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.5,max_nn=200))

for i in range(70,72):
	local_pcd = o3d.geometry.PointCloud()
	local_pcd.points = o3d.utility.Vector3dVector(dataset[i].point_cloud[:, :3])
	
	
	## label visualization 
	labeled_pcd = o3d.geometry.PointCloud()
	labeled_pcd.points = o3d.utility.Vector3dVector(dataset[i].point_cloud[:, :3])
	labeled_pcd.colors = o3d.utility.Vector3dVector(np.vstack([0,0,0] for i in range(np.asarray(labeled_pcd.points).shape[0])))
	panoptic_labels = dataset[i].panoptic_labels # semantics + panoptics combined 
	semantic_labels = dataset[i].semantic_labels
	instance_labels = dataset[i].instance_labels
	intensity = dataset[i].intensity
	
	transform = dataset.get_pose(i)
	local_pcd.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.5,max_nn=200))
	reg_p2l = registration.registration_icp(local_pcd, merge, 0.9, transform, registration.TransformationEstimationPointToPlane(), registration.ICPConvergenceCriteria(max_iteration=1000))
	transform = reg_p2l.transformation
	local_pcd.transform(transform)
	
	local_pcd.normals = o3d.utility.Vector3dVector([])
	
	local_pcd.paint_uniform_color([0, 0, 0])
	
	
	
	
	colors, labels,local_labels = kDTree_1NN_feature_reprojection_colors(np.asarray(local_pcd.colors), local_pcd, np.asarray(merge.colors), merge,panoptic_labels, max_radius=0.2)
	labeled_pcd = color_pcd_by_labels(labeled_pcd,labels.reshape(-1,))
	local_pcd.colors = o3d.utility.Vector3dVector(colors)
	#o3d.io.write_point_cloud("test.pcd", local_pcd, write_ascii=False, compressed=False, print_progress=False)
	
	
	
	labeled_pcd.translate([0,120,0])
	o3d.visualization.draw_geometries([local_pcd,labeled_pcd])
	unique_colors, labels = np.unique(colors, axis=0, return_inverse=True)
	unseen_mask = np.all(colors == [1,0,0], axis=1)
	labels[unseen_mask] = -1
	street_mask = np.all(colors == [0,0,0], axis=1)
	labels[street_mask] = 1
	
	#np.savez('output_files/7_tarl/ ' + str(i) + '.npz',labels=labels)

	

	#np.savez('output_files/7_original/' + str(i) + '.npz',ncut_labels=local_labels,kitti_labels=labels,pts=np.asarray(local_pcd.points),           
	#intensities=intensity,kitti_labels_semantic=semantic_labels,kitti_labels_instance=instance_labels)

# %%
import numpy as np 
with np.load('output_files/7_original/0.npz') as data:
            xyz = data['pts'].astype(np.float)
            labels = data['ncut_labels'].astype(np.int32)  
            kitti_labels = data['kitti_labels']
            intensity = data['intensities']
            
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(xyz)
pcd = color_pcd_by_labels(pcd,labels)
o3d.visualization.draw_geometries([pcd])
