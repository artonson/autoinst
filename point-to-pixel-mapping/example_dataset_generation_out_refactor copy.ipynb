# %%
import numpy as np
import os
import sys
import cv2
import matplotlib.pyplot as plt
import open3d as o3d
# %matplotlib inline 

src_path = os.path.abspath("../..")
if src_path not in sys.path:
    sys.path.append(src_path)
# %load_ext autoreload
from dataset.kitti_odometry_dataset import KittiOdometryDataset, KittiOdometryDatasetConfig
from dataset.filters.filter_list import FilterList
from dataset.filters.kitti_gt_mo_filter import KittiGTMovingObjectFilter
from dataset.filters.range_filter import RangeFilter
from dataset.filters.apply_pose import ApplyPose

import scipy
from scipy.spatial.distance import cdist
from normalized_cut import normalized_cut
from ncuts_utils import ncuts_chunk,kDTree_1NN_feature_reprojection_colors, get_merge_pcds
from dataset_utils import * 
from point_cloud_utils import get_pcd, transform_pcd, kDTree_1NN_feature_reprojection, remove_isolated_points, get_subpcd, get_statistical_inlier_indices, merge_chunks_unite_instances
from aggregate_pointcloud import aggregate_pointcloud
from visualization_utils import generate_random_colors, color_pcd_by_labels,generate_random_colors_map
from sam_label_distace import sam_label_distance
from chunk_generation import subsample_positions, chunks_from_pointcloud, indices_per_patch, tarl_features_per_patch, image_based_features_per_patch, dinov2_mean, get_indices_feature_reprojection
from metrics.metrics_class import Metrics
import matplotlib.pyplot as plt 
import shutil
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [(0.267004, 0.004874, 0.329415), (0.277018, 0.050344, 0.375715), (0.282656, 0.100196, 0.42216), (0.28229, 0.145912, 0.46151), (0.276194, 0.190074, 0.493001), (0.265145, 0.232956, 0.516599), (0.252194, 0.269783, 0.531579), (0.235526, 0.309527, 0.542944), (0.21813, 0.347432, 0.550038), (0.201239, 0.38367, 0.554294), (0.185556, 0.41857, 0.556753), (0.171176, 0.45253, 0.557965), (0.159194, 0.482237, 0.558073), (0.14618, 0.515413, 0.556823), (0.133743, 0.548535, 0.553541), (0.123463, 0.581687, 0.547445), (0.119483, 0.614817, 0.537692), (0.128087, 0.647749, 0.523491), (0.150148, 0.676631, 0.506589), (0.19109, 0.708366, 0.482284), (0.24607, 0.73891, 0.452024), (0.311925, 0.767822, 0.415586), (0.386433, 0.794644, 0.372886), (0.468053, 0.818921, 0.323998), (0.545524, 0.838039, 0.275626), (0.636902, 0.856542, 0.21662), (0.730889, 0.871916, 0.156029), (0.82494, 0.88472, 0.106217), (0.916242, 0.896091, 0.100717), (0.993248, 0.906157, 0.143936)]

# %% [markdown]
# Here we define the dataset depending on kitti sequence!

# %%
DATASET_PATH = os.path.join('/media/cedric/Datasets1/semantic_kitti/')
end_inds = {0:4541,1:1100,2:4661,3:800,4:271,5:2761,6:1101,7:1100,8:4071,9:1591,10:1201}
SEQUENCE_NUM = 5

ind_start = 0
ind_end = end_inds[SEQUENCE_NUM]
minor_voxel_size = 0.05
major_voxel_size = 0.35
chunk_size = np.array([25, 10, 25]) #meters
overlap = 3 #meters
ground_segmentation_method = 'patchwork' 
NCUT_ground = False

out_chunks = 'pcd_preprocessed/output_chunks/'

out_folder_ncuts = out_chunks + 'test_data_ncuts/'
if os.path.exists(out_folder_ncuts):
        shutil.rmtree(out_folder_ncuts)
os.makedirs(out_folder_ncuts)

dataset = create_kitti_odometry_dataset(DATASET_PATH,SEQUENCE_NUM,ncuts_mode=True)

out_folder = 'pcd_preprocessed/'
if os.path.exists(out_folder) == False : 
        os.makedirs(out_folder)

# %% [markdown]
# Now we aggregate a large point cloud based on (ind_start, ind_end)
# ## This cell can be ignored after first run as outputs are stored

# %%
if os.path.exists(out_folder + 'all_poses_' + str(SEQUENCE_NUM) + '_' + str(0) + '.npz') == False:
        process_and_save_point_clouds(dataset,ind_start,ind_end,minor_voxel_size=minor_voxel_size,
                                major_voxel_size=major_voxel_size,icp=False,
                                out_folder=out_folder,sequence_num=SEQUENCE_NUM,
                                ground_segmentation_method=ground_segmentation_method)

# %% [markdown]
# This cell can be ignored after first run as outputs are stored

# %%
##load data if already stored 

if os.path.exists(f'{out_folder}pcd_ground_minor{SEQUENCE_NUM}_0.pcd') == False:
        pcd_ground_minor, pcd_nonground_minor,\
                all_poses, T_pcd, first_position,kitti_labels = load_and_downsample_point_clouds(out_folder,SEQUENCE_NUM,minor_voxel_size,\
                                                                        ground_mode=ground_segmentation_method)
        #o3d.visualization.draw_geometries([color_pcd_by_labels(pcd_nonground_minor,kitti_labels['seg_nonground'])])
        o3d.io.write_point_cloud(f'{out_folder}pcd_ground_minor{SEQUENCE_NUM}_0.pcd', pcd_ground_minor, write_ascii=False, compressed=False, print_progress=False)
        o3d.io.write_point_cloud(f'{out_folder}pcd_nonground_minor{SEQUENCE_NUM}_0.pcd', pcd_nonground_minor, write_ascii=False, compressed=False, print_progress=False)
        np.savez(f'{out_folder}kitti_labels_preprocessed{SEQUENCE_NUM}_0.npz',
                                                instance_nonground=kitti_labels['instance_nonground'],
                                                instance_ground=kitti_labels['instance_ground'],
                                                seg_ground = kitti_labels['seg_ground'],
                                                seg_nonground=kitti_labels['seg_nonground']
                                                )
        o3d.visualization.draw_geometries([pcd_nonground_minor])

# %%
pcd_ground_minor = o3d.io.read_point_cloud(f'{out_folder}pcd_ground_minor{SEQUENCE_NUM}_0.pcd')
pcd_nonground_minor = o3d.io.read_point_cloud(f'{out_folder}pcd_nonground_minor{SEQUENCE_NUM}_0.pcd')
print(pcd_ground_minor)
kitti_labels_orig = {}
with np.load(f'{out_folder}kitti_labels_preprocessed{SEQUENCE_NUM}_0.npz') as data :
        kitti_labels_orig['instance_ground'] = data['instance_ground']
        kitti_labels_orig['instance_nonground'] = data['instance_nonground']
        kitti_labels_orig['seg_nonground'] = data['seg_nonground']
        kitti_labels_orig['seg_ground'] = data['seg_ground']

        

with np.load(f'{out_folder}all_poses_{SEQUENCE_NUM}_0.npz') as data:
        all_poses = data['all_poses']
        T_pcd = data['T_pcd']
        first_position = T_pcd[:3, 3]
# Out:
# PointCloud with 28982347 points.

# %%
'''
pcd_new = o3d.geometry.PointCloud()
pts_num = 1000000
pcd_new.points = o3d.utility.Vector3dVector(np.asarray(pcd_nonground_minor.points)[:pts_num])

map_labelled = color_pcd_by_labels(pcd_new,\
                kitti_labels['panoptic_nonground'][:pts_num].reshape(-1,1))

o3d.visualization.draw_geometries([map_labelled])
#o3d.io.write_point_cloud('labelled_map07.pcd',map_labelled)
'''
# Out:
# "\npcd_new = o3d.geometry.PointCloud()\npts_num = 1000000\npcd_new.points = o3d.utility.Vector3dVector(np.asarray(pcd_nonground_minor.points)[:pts_num])\n\nmap_labelled = color_pcd_by_labels(pcd_new,                kitti_labels['panoptic_nonground'][:pts_num].reshape(-1,1))\n\no3d.visualization.draw_geometries([map_labelled])\n#o3d.io.write_point_cloud('labelled_map07.pcd',map_labelled)\n"

# %% [markdown]
# Now we subsample the poses based on a voxel_size

# %%
if os.path.exists(f'{out_folder}subsampled_data{str(SEQUENCE_NUM)}_0.npz') ==  False : 
	print(f'{out_folder}subsampled_data{str(SEQUENCE_NUM)}_0.npz')
	poses, positions, \
	sampled_indices_local, sampled_indices_global = subsample_and_extract_positions(all_poses,ind_start=ind_start,sequence_num=SEQUENCE_NUM,out_folder=out_folder)

# %%
with np.load(f'{out_folder}subsampled_data{SEQUENCE_NUM}_0.npz') as data:
	poses=data['poses']
	positions=data['positions']
	sampled_indices_local = data['sampled_indices_local']
	sampled_indices_global=data['sampled_indices_global']

# %% [markdown]
# Now we can split the point cloud into chunks based on a tbd chunk_size

# %%
overlap = 3
pcd_nonground_chunks, pcd_ground_chunks,\
pcd_nonground_chunks_major_downsampling, pcd_ground_chunks_major_downsampling, \
indices,indices_ground, center_positions, \
center_ids, chunk_bounds, kitti_labels = chunk_and_downsample_point_clouds(pcd_nonground_minor, pcd_ground_minor, T_pcd, positions, 
                                                            first_position, sampled_indices_global, chunk_size=chunk_size, 
                                                            overlap=overlap, major_voxel_size=major_voxel_size,kitti_labels=kitti_labels_orig)
# Out:
# Downsampled from (66041, 3) to (888, 3) points (non-ground)
# Downsampled from (250772, 3) to (3070, 3) points (ground)
# Downsampled from (97146, 3) to (1212, 3) points (non-ground)
# Downsampled from (259555, 3) to (2697, 3) points (ground)
# Downsampled from (137581, 3) to (1698, 3) points (non-ground)
# Downsampled from (258422, 3) to (3407, 3) points (ground)
# Downsampled from (154463, 3) to (1921, 3) points (non-ground)
# Downsampled from (253497, 3) to (3092, 3) points (ground)
# Downsampled from (133251, 3) to (1765, 3) points (non-ground)
# Downsampled from (244982, 3) to (2909, 3) points (ground)
# Downsampled from (135506, 3) to (1599, 3) points (non-ground)
# Downsampled from (236036, 3) to (2899, 3) points (ground)
# Downsampled from (114476, 3) to (1531, 3) points (non-ground)
# Downsampled from (243396, 3) to (2973, 3) points (ground)
# Downsampled from (100986, 3) to (1433, 3) points (non-ground)
# Downsampled from (248638, 3) to (2942, 3) points (ground)
# Downsampled from (71857, 3) to (1176, 3) points (non-ground)
# Downsampled from (254545, 3) to (3082, 3) points (ground)
# Downsampled from (57332, 3) to (984, 3) points (non-ground)
# Downsampled from (258138, 3) to (3109, 3) points (ground)
# Downsampled from (91053, 3) to (1452, 3) points (non-ground)
# Downsampled from (261973, 3) to (3104, 3) points (ground)
# Downsampled from (51304, 3) to (1081, 3) points (non-ground)
# Downsampled from (262556, 3) to (2988, 3) points (ground)
# Downsampled from (114093, 3) to (1471, 3) points (non-ground)
# Downsampled from (254682, 3) to (3102, 3) points (ground)
# Downsampled from (374953, 3) to (4781, 3) points (non-ground)
# Downsampled from (199639, 3) to (3084, 3) points (ground)
# Downsampled from (282598, 3) to (4123, 3) points (non-ground)
# Downsampled from (146482, 3) to (2757, 3) points (ground)
# Downsampled from (224685, 3) to (3326, 3) points (non-ground)
# Downsampled from (107964, 3) to (2186, 3) points (ground)
# Downsampled from (146759, 3) to (2259, 3) points (non-ground)
# Downsampled from (134361, 3) to (2492, 3) points (ground)
# Downsampled from (154168, 3) to (2493, 3) points (non-ground)
# Downsampled from (148450, 3) to (3037, 3) points (ground)
# Downsampled from (191761, 3) to (2995, 3) points (non-ground)
# Downsampled from (131196, 3) to (2621, 3) points (ground)
# Downsampled from (185626, 3) to (2942, 3) points (non-ground)
# Downsampled from (118271, 3) to (2257, 3) points (ground)
# Downsampled from (213565, 3) to (3313, 3) points (non-ground)
# Downsampled from (102770, 3) to (1978, 3) points (ground)
# Downsampled from (168035, 3) to (2731, 3) points (non-ground)
# Downsampled from (109207, 3) to (2176, 3) points (ground)
# Downsampled from (223193, 3) to (3709, 3) points (non-ground)
# Downsampled from (118022, 3) to (2866, 3) points (ground)
# Downsampled from (249286, 3) to (4550, 3) points (non-ground)
# Downsampled from (122440, 3) to (2904, 3) points (ground)
# Downsampled from (157842, 3) to (2817, 3) points (non-ground)
# Downsampled from (125618, 3) to (2519, 3) points (ground)
# Downsampled from (182145, 3) to (2680, 3) points (non-ground)
# Downsampled from (106695, 3) to (2242, 3) points (ground)
# Downsampled from (209772, 3) to (3050, 3) points (non-ground)
# Downsampled from (113494, 3) to (2122, 3) points (ground)
# Downsampled from (136144, 3) to (2434, 3) points (non-ground)
# Downsampled from (147148, 3) to (2746, 3) points (ground)
# Downsampled from (109200, 3) to (2026, 3) points (non-ground)
# Downsampled from (153361, 3) to (2767, 3) points (ground)
# Downsampled from (173317, 3) to (2927, 3) points (non-ground)
# Downsampled from (126258, 3) to (2195, 3) points (ground)
# Downsampled from (167637, 3) to (2597, 3) points (non-ground)
# Downsampled from (133746, 3) to (2285, 3) points (ground)
# Downsampled from (215203, 3) to (3772, 3) points (non-ground)
# Downsampled from (127351, 3) to (2481, 3) points (ground)
# Downsampled from (307543, 3) to (5038, 3) points (non-ground)
# Downsampled from (126252, 3) to (2628, 3) points (ground)
# Downsampled from (237296, 3) to (4201, 3) points (non-ground)
# Downsampled from (111105, 3) to (2237, 3) points (ground)
# Downsampled from (265889, 3) to (4206, 3) points (non-ground)
# Downsampled from (109442, 3) to (2310, 3) points (ground)
# Downsampled from (239849, 3) to (3434, 3) points (non-ground)
# Downsampled from (129602, 3) to (2205, 3) points (ground)
# Downsampled from (192779, 3) to (2689, 3) points (non-ground)
# Downsampled from (147390, 3) to (2225, 3) points (ground)
# Downsampled from (150805, 3) to (2156, 3) points (non-ground)
# Downsampled from (175432, 3) to (2421, 3) points (ground)
# Downsampled from (149818, 3) to (1862, 3) points (non-ground)
# Downsampled from (185965, 3) to (2351, 3) points (ground)
# Downsampled from (132918, 3) to (2047, 3) points (non-ground)
# Downsampled from (188491, 3) to (2511, 3) points (ground)
# Downsampled from (86019, 3) to (1364, 3) points (non-ground)
# Downsampled from (206693, 3) to (2350, 3) points (ground)
# Downsampled from (88731, 3) to (1142, 3) points (non-ground)
# Downsampled from (199497, 3) to (3401, 3) points (ground)
# Downsampled from (109149, 3) to (1496, 3) points (non-ground)
# Downsampled from (197575, 3) to (3364, 3) points (ground)
# Downsampled from (117365, 3) to (1784, 3) points (non-ground)
# Downsampled from (199980, 3) to (3403, 3) points (ground)
# Downsampled from (115855, 3) to (2027, 3) points (non-ground)
# Downsampled from (219798, 3) to (3397, 3) points (ground)
# Downsampled from (97279, 3) to (1583, 3) points (non-ground)
# Downsampled from (246810, 3) to (3616, 3) points (ground)
# Downsampled from (107473, 3) to (1389, 3) points (non-ground)
# Downsampled from (266840, 3) to (3862, 3) points (ground)
# Downsampled from (152298, 3) to (1805, 3) points (non-ground)
# Downsampled from (258556, 3) to (3793, 3) points (ground)
# Downsampled from (315975, 3) to (3575, 3) points (non-ground)
# Downsampled from (203896, 3) to (2722, 3) points (ground)
# Downsampled from (310242, 3) to (3547, 3) points (non-ground)
# Downsampled from (193836, 3) to (2933, 3) points (ground)
# Downsampled from (272561, 3) to (3404, 3) points (non-ground)
# Downsampled from (171832, 3) to (3071, 3) points (ground)
# Downsampled from (266297, 3) to (3481, 3) points (non-ground)
# Downsampled from (138418, 3) to (2287, 3) points (ground)
# Downsampled from (237202, 3) to (2990, 3) points (non-ground)
# Downsampled from (147342, 3) to (2586, 3) points (ground)
# Downsampled from (212157, 3) to (2797, 3) points (non-ground)
# Downsampled from (147055, 3) to (2467, 3) points (ground)
# Downsampled from (212671, 3) to (3204, 3) points (non-ground)
# Downsampled from (163964, 3) to (2983, 3) points (ground)
# Downsampled from (205097, 3) to (2931, 3) points (non-ground)
# Downsampled from (147164, 3) to (2484, 3) points (ground)
# Downsampled from (214301, 3) to (3279, 3) points (non-ground)
# Downsampled from (124069, 3) to (2597, 3) points (ground)
# Downsampled from (229078, 3) to (3140, 3) points (non-ground)
# Downsampled from (153261, 3) to (2931, 3) points (ground)
# Downsampled from (221991, 3) to (3165, 3) points (non-ground)
# Downsampled from (154064, 3) to (2825, 3) points (ground)
# Downsampled from (227410, 3) to (2897, 3) points (non-ground)
# Downsampled from (124071, 3) to (2172, 3) points (ground)
# Downsampled from (241985, 3) to (3166, 3) points (non-ground)
# Downsampled from (143879, 3) to (2758, 3) points (ground)
# Downsampled from (200463, 3) to (2657, 3) points (non-ground)
# Downsampled from (151992, 3) to (2595, 3) points (ground)
# Downsampled from (176458, 3) to (2300, 3) points (non-ground)
# Downsampled from (133450, 3) to (2173, 3) points (ground)
# Downsampled from (117772, 3) to (1585, 3) points (non-ground)
# Downsampled from (157468, 3) to (2198, 3) points (ground)
# Downsampled from (103486, 3) to (1499, 3) points (non-ground)
# Downsampled from (180304, 3) to (2627, 3) points (ground)
# Downsampled from (128356, 3) to (1966, 3) points (non-ground)
# Downsampled from (172126, 3) to (2659, 3) points (ground)
# Downsampled from (161427, 3) to (2187, 3) points (non-ground)
# Downsampled from (139780, 3) to (2096, 3) points (ground)
# Downsampled from (184990, 3) to (2375, 3) points (non-ground)
# Downsampled from (135248, 3) to (1967, 3) points (ground)
# Downsampled from (205549, 3) to (2717, 3) points (non-ground)
# Downsampled from (148044, 3) to (2382, 3) points (ground)
# Downsampled from (247871, 3) to (3107, 3) points (non-ground)
# Downsampled from (144160, 3) to (2451, 3) points (ground)
# Downsampled from (310589, 3) to (3758, 3) points (non-ground)
# Downsampled from (141421, 3) to (2651, 3) points (ground)
# Downsampled from (323704, 3) to (3723, 3) points (non-ground)
# Downsampled from (151090, 3) to (2533, 3) points (ground)
# Downsampled from (296920, 3) to (3659, 3) points (non-ground)
# Downsampled from (169859, 3) to (2622, 3) points (ground)
# Downsampled from (340113, 3) to (3391, 3) points (non-ground)
# Downsampled from (240661, 3) to (3478, 3) points (ground)
# Downsampled from (156265, 3) to (1512, 3) points (non-ground)
# Downsampled from (285822, 3) to (3135, 3) points (ground)
# Downsampled from (108420, 3) to (1443, 3) points (non-ground)
# Downsampled from (295117, 3) to (3109, 3) points (ground)
# Downsampled from (119981, 3) to (1367, 3) points (non-ground)
# Downsampled from (277942, 3) to (2980, 3) points (ground)
# Downsampled from (117891, 3) to (1408, 3) points (non-ground)
# Downsampled from (268841, 3) to (3138, 3) points (ground)
# Downsampled from (145879, 3) to (1701, 3) points (non-ground)
# Downsampled from (260046, 3) to (3011, 3) points (ground)
# Downsampled from (140058, 3) to (1730, 3) points (non-ground)
# Downsampled from (262586, 3) to (3135, 3) points (ground)
# Downsampled from (97237, 3) to (1481, 3) points (non-ground)
# Downsampled from (251350, 3) to (3235, 3) points (ground)
# Downsampled from (242573, 3) to (3546, 3) points (non-ground)
# Downsampled from (188130, 3) to (2951, 3) points (ground)
# Downsampled from (262603, 3) to (3759, 3) points (non-ground)
# Downsampled from (134771, 3) to (2501, 3) points (ground)
# Downsampled from (193431, 3) to (2885, 3) points (non-ground)
# Downsampled from (105247, 3) to (1827, 3) points (ground)
# Downsampled from (116251, 3) to (2112, 3) points (non-ground)
# Downsampled from (100812, 3) to (1758, 3) points (ground)
# Downsampled from (155997, 3) to (2872, 3) points (non-ground)
# Downsampled from (112759, 3) to (2625, 3) points (ground)
# Downsampled from (171263, 3) to (2734, 3) points (non-ground)
# Downsampled from (118646, 3) to (2516, 3) points (ground)
# Downsampled from (177177, 3) to (2886, 3) points (non-ground)
# Downsampled from (99830, 3) to (2158, 3) points (ground)
# Downsampled from (201934, 3) to (2836, 3) points (non-ground)
# Downsampled from (123281, 3) to (2370, 3) points (ground)
# Downsampled from (145809, 3) to (2267, 3) points (non-ground)
# Downsampled from (154551, 3) to (2557, 3) points (ground)
# Downsampled from (177096, 3) to (2717, 3) points (non-ground)
# Downsampled from (152228, 3) to (2996, 3) points (ground)
# Downsampled from (214369, 3) to (3203, 3) points (non-ground)
# Downsampled from (132711, 3) to (2082, 3) points (ground)
# Downsampled from (214559, 3) to (2909, 3) points (non-ground)
# Downsampled from (112217, 3) to (1832, 3) points (ground)
# Downsampled from (151101, 3) to (2127, 3) points (non-ground)
# Downsampled from (126061, 3) to (2293, 3) points (ground)
# Downsampled from (252687, 3) to (3760, 3) points (non-ground)
# Downsampled from (129483, 3) to (2434, 3) points (ground)
# Downsampled from (98401, 3) to (1859, 3) points (non-ground)
# Downsampled from (141263, 3) to (2280, 3) points (ground)
# Downsampled from (151693, 3) to (2354, 3) points (non-ground)
# Downsampled from (121917, 3) to (2016, 3) points (ground)
# Downsampled from (155365, 3) to (2123, 3) points (non-ground)
# Downsampled from (102288, 3) to (1884, 3) points (ground)
# Downsampled from (170656, 3) to (2443, 3) points (non-ground)
# Downsampled from (107712, 3) to (2213, 3) points (ground)
# Downsampled from (184591, 3) to (2861, 3) points (non-ground)
# Downsampled from (125067, 3) to (2774, 3) points (ground)
# Downsampled from (168587, 3) to (2627, 3) points (non-ground)
# Downsampled from (111801, 3) to (2538, 3) points (ground)
# Downsampled from (201196, 3) to (3216, 3) points (non-ground)
# Downsampled from (103744, 3) to (2360, 3) points (ground)
# Downsampled from (176343, 3) to (2732, 3) points (non-ground)
# Downsampled from (123422, 3) to (2388, 3) points (ground)
# Downsampled from (171047, 3) to (2908, 3) points (non-ground)
# Downsampled from (129562, 3) to (2340, 3) points (ground)
# Downsampled from (161634, 3) to (2745, 3) points (non-ground)
# Downsampled from (120324, 3) to (2469, 3) points (ground)
# Downsampled from (175037, 3) to (2708, 3) points (non-ground)
# Downsampled from (139869, 3) to (2399, 3) points (ground)
# Downsampled from (176794, 3) to (2850, 3) points (non-ground)
# Downsampled from (120743, 3) to (2093, 3) points (ground)
# Downsampled from (212805, 3) to (3373, 3) points (non-ground)
# Downsampled from (93829, 3) to (1872, 3) points (ground)
# Downsampled from (246867, 3) to (3503, 3) points (non-ground)
# Downsampled from (82793, 3) to (1583, 3) points (ground)
# Downsampled from (276400, 3) to (4228, 3) points (non-ground)
# Downsampled from (138331, 3) to (2333, 3) points (ground)
# Downsampled from (181166, 3) to (2515, 3) points (non-ground)
# Downsampled from (163667, 3) to (2296, 3) points (ground)
# Downsampled from (140480, 3) to (1975, 3) points (non-ground)
# Downsampled from (189177, 3) to (3142, 3) points (ground)
# Downsampled from (78264, 3) to (1063, 3) points (non-ground)
# Downsampled from (216983, 3) to (3896, 3) points (ground)
# Downsampled from (105181, 3) to (1460, 3) points (non-ground)
# Downsampled from (212443, 3) to (3627, 3) points (ground)
# Downsampled from (123470, 3) to (1828, 3) points (non-ground)
# Downsampled from (193277, 3) to (3368, 3) points (ground)
# Downsampled from (134724, 3) to (2003, 3) points (non-ground)
# Downsampled from (182847, 3) to (3325, 3) points (ground)
# Downsampled from (126590, 3) to (1732, 3) points (non-ground)
# Downsampled from (195985, 3) to (3509, 3) points (ground)
# Downsampled from (187904, 3) to (2690, 3) points (non-ground)
# Downsampled from (197774, 3) to (3590, 3) points (ground)
# Downsampled from (139554, 3) to (2164, 3) points (non-ground)
# Downsampled from (212012, 3) to (3296, 3) points (ground)
# Downsampled from (309756, 3) to (3503, 3) points (non-ground)
# Downsampled from (218759, 3) to (2957, 3) points (ground)
# Downsampled from (304570, 3) to (3511, 3) points (non-ground)
# Downsampled from (205495, 3) to (3081, 3) points (ground)
# Downsampled from (272798, 3) to (3493, 3) points (non-ground)
# Downsampled from (168685, 3) to (3066, 3) points (ground)
# Downsampled from (225049, 3) to (3002, 3) points (non-ground)
# Downsampled from (144739, 3) to (2396, 3) points (ground)
# Downsampled from (210940, 3) to (2678, 3) points (non-ground)
# Downsampled from (145098, 3) to (2549, 3) points (ground)
# Downsampled from (221769, 3) to (3247, 3) points (non-ground)
# Downsampled from (158673, 3) to (2607, 3) points (ground)
# Downsampled from (226309, 3) to (3230, 3) points (non-ground)
# Downsampled from (157799, 3) to (2542, 3) points (ground)
# Downsampled from (216865, 3) to (3312, 3) points (non-ground)
# Downsampled from (126817, 3) to (2527, 3) points (ground)
# Downsampled from (239727, 3) to (3293, 3) points (non-ground)
# Downsampled from (134922, 3) to (2684, 3) points (ground)
# Downsampled from (180961, 3) to (2376, 3) points (non-ground)
# Downsampled from (145660, 3) to (2198, 3) points (ground)
# Downsampled from (230710, 3) to (2930, 3) points (non-ground)
# Downsampled from (123837, 3) to (2121, 3) points (ground)
# Downsampled from (201387, 3) to (2820, 3) points (non-ground)
# Downsampled from (132566, 3) to (2615, 3) points (ground)
# Downsampled from (157437, 3) to (2218, 3) points (non-ground)
# Downsampled from (149598, 3) to (2689, 3) points (ground)
# Downsampled from (173504, 3) to (2256, 3) points (non-ground)
# Downsampled from (131325, 3) to (2006, 3) points (ground)
# Downsampled from (111154, 3) to (1487, 3) points (non-ground)
# Downsampled from (161424, 3) to (2278, 3) points (ground)
# Downsampled from (106965, 3) to (1632, 3) points (non-ground)
# Downsampled from (181358, 3) to (2761, 3) points (ground)
# Downsampled from (161441, 3) to (2202, 3) points (non-ground)
# Downsampled from (139238, 3) to (2074, 3) points (ground)
# Downsampled from (220924, 3) to (2888, 3) points (non-ground)
# Downsampled from (149149, 3) to (2508, 3) points (ground)
# Downsampled from (267500, 3) to (3249, 3) points (non-ground)
# Downsampled from (140657, 3) to (2461, 3) points (ground)
# Downsampled from (323704, 3) to (3707, 3) points (non-ground)
# Downsampled from (150978, 3) to (2522, 3) points (ground)
# Downsampled from (308999, 3) to (3696, 3) points (non-ground)
# Downsampled from (171646, 3) to (2646, 3) points (ground)
# Downsampled from (342008, 3) to (3366, 3) points (non-ground)
# Downsampled from (240897, 3) to (3484, 3) points (ground)
# Downsampled from (24695, 3) to (840, 3) points (non-ground)
# Downsampled from (279344, 3) to (3137, 3) points (ground)
# Downsampled from (184622, 3) to (2536, 3) points (non-ground)
# Downsampled from (251788, 3) to (2764, 3) points (ground)
# Downsampled from (289057, 3) to (3337, 3) points (non-ground)
# Downsampled from (153995, 3) to (2615, 3) points (ground)
# Downsampled from (221615, 3) to (3934, 3) points (non-ground)
# Downsampled from (114979, 3) to (2507, 3) points (ground)
# Downsampled from (183730, 3) to (3463, 3) points (non-ground)
# Downsampled from (112679, 3) to (2361, 3) points (ground)
# Downsampled from (143117, 3) to (2739, 3) points (non-ground)
# Downsampled from (107420, 3) to (2181, 3) points (ground)
# Downsampled from (153541, 3) to (2493, 3) points (non-ground)
# Downsampled from (90455, 3) to (1759, 3) points (ground)
# Downsampled from (141159, 3) to (2621, 3) points (non-ground)
# Downsampled from (119895, 3) to (2640, 3) points (ground)
# Downsampled from (109967, 3) to (2444, 3) points (non-ground)
# Downsampled from (128270, 3) to (2515, 3) points (ground)
# Downsampled from (182975, 3) to (3138, 3) points (non-ground)
# Downsampled from (104619, 3) to (2448, 3) points (ground)
# Downsampled from (205238, 3) to (3263, 3) points (non-ground)
# Downsampled from (94224, 3) to (2005, 3) points (ground)
# Downsampled from (158234, 3) to (2569, 3) points (non-ground)
# Downsampled from (125549, 3) to (2533, 3) points (ground)
# Downsampled from (110343, 3) to (2018, 3) points (non-ground)
# Downsampled from (145198, 3) to (2683, 3) points (ground)
# Downsampled from (132352, 3) to (2203, 3) points (non-ground)
# Downsampled from (119374, 3) to (2052, 3) points (ground)
# Downsampled from (222539, 3) to (3007, 3) points (non-ground)
# Downsampled from (105027, 3) to (1967, 3) points (ground)
# Downsampled from (138356, 3) to (2052, 3) points (non-ground)
# Downsampled from (128496, 3) to (2115, 3) points (ground)
# Downsampled from (90526, 3) to (1604, 3) points (non-ground)
# Downsampled from (143497, 3) to (2755, 3) points (ground)
# Downsampled from (193688, 3) to (2817, 3) points (non-ground)
# Downsampled from (104473, 3) to (2137, 3) points (ground)
# Downsampled from (177410, 3) to (2778, 3) points (non-ground)
# Downsampled from (101546, 3) to (2031, 3) points (ground)
# Downsampled from (133817, 3) to (2364, 3) points (non-ground)
# Downsampled from (128842, 3) to (2409, 3) points (ground)
# Downsampled from (162623, 3) to (2745, 3) points (non-ground)
# Downsampled from (116994, 3) to (2493, 3) points (ground)
# Downsampled from (182768, 3) to (2755, 3) points (non-ground)
# Downsampled from (96733, 3) to (1727, 3) points (ground)
# Downsampled from (182171, 3) to (3148, 3) points (non-ground)
# Downsampled from (102034, 3) to (1926, 3) points (ground)
# Downsampled from (127027, 3) to (2456, 3) points (non-ground)
# Downsampled from (126972, 3) to (2414, 3) points (ground)
# Downsampled from (165392, 3) to (2373, 3) points (non-ground)
# Downsampled from (111186, 3) to (2280, 3) points (ground)
# Downsampled from (224906, 3) to (3559, 3) points (non-ground)
# Downsampled from (78403, 3) to (2068, 3) points (ground)
# Downsampled from (258301, 3) to (4584, 3) points (non-ground)
# Downsampled from (86838, 3) to (2402, 3) points (ground)
# Downsampled from (199563, 3) to (3177, 3) points (non-ground)
# Downsampled from (132764, 3) to (2539, 3) points (ground)
# Downsampled from (185594, 3) to (2827, 3) points (non-ground)
# Downsampled from (137402, 3) to (2417, 3) points (ground)
# Downsampled from (264519, 3) to (3630, 3) points (non-ground)
# Downsampled from (127867, 3) to (2359, 3) points (ground)
# Downsampled from (282932, 3) to (3551, 3) points (non-ground)
# Downsampled from (162813, 3) to (2336, 3) points (ground)
# Downsampled from (227157, 3) to (3358, 3) points (non-ground)
# Downsampled from (197346, 3) to (2766, 3) points (ground)
# Downsampled from (166442, 3) to (2803, 3) points (non-ground)
# Downsampled from (199249, 3) to (2926, 3) points (ground)
# Downsampled from (127859, 3) to (1913, 3) points (non-ground)
# Downsampled from (194610, 3) to (2792, 3) points (ground)
# Downsampled from (128944, 3) to (2066, 3) points (non-ground)
# Downsampled from (181780, 3) to (2722, 3) points (ground)
# Downsampled from (85748, 3) to (1461, 3) points (non-ground)
# Downsampled from (186267, 3) to (2670, 3) points (ground)
# Downsampled from (101037, 3) to (1612, 3) points (non-ground)
# Downsampled from (187923, 3) to (2750, 3) points (ground)
# Downsampled from (86475, 3) to (1409, 3) points (non-ground)
# Downsampled from (190313, 3) to (2709, 3) points (ground)
# Downsampled from (74727, 3) to (1103, 3) points (non-ground)
# Downsampled from (190920, 3) to (2756, 3) points (ground)
# Downsampled from (88220, 3) to (1067, 3) points (non-ground)
# Downsampled from (191969, 3) to (2728, 3) points (ground)
# Downsampled from (64592, 3) to (954, 3) points (non-ground)
# Downsampled from (195796, 3) to (2719, 3) points (ground)
# Downsampled from (57146, 3) to (938, 3) points (non-ground)
# Downsampled from (189175, 3) to (2834, 3) points (ground)
# Downsampled from (41012, 3) to (871, 3) points (non-ground)
# Downsampled from (188542, 3) to (2754, 3) points (ground)
# Downsampled from (52531, 3) to (1137, 3) points (non-ground)
# Downsampled from (180102, 3) to (2799, 3) points (ground)
# Downsampled from (54046, 3) to (1109, 3) points (non-ground)
# Downsampled from (183327, 3) to (2748, 3) points (ground)
# Downsampled from (69394, 3) to (1362, 3) points (non-ground)
# Downsampled from (180319, 3) to (2740, 3) points (ground)
# Downsampled from (79293, 3) to (1592, 3) points (non-ground)
# Downsampled from (175063, 3) to (2779, 3) points (ground)
# Downsampled from (86453, 3) to (1727, 3) points (non-ground)
# Downsampled from (173135, 3) to (2821, 3) points (ground)
# Downsampled from (78007, 3) to (1526, 3) points (non-ground)
# Downsampled from (174571, 3) to (2863, 3) points (ground)
# Downsampled from (81357, 3) to (1583, 3) points (non-ground)
# Downsampled from (178440, 3) to (2859, 3) points (ground)
# Downsampled from (64031, 3) to (1379, 3) points (non-ground)
# Downsampled from (185428, 3) to (2776, 3) points (ground)
# Downsampled from (55439, 3) to (1127, 3) points (non-ground)
# Downsampled from (194164, 3) to (2733, 3) points (ground)
# Downsampled from (41407, 3) to (759, 3) points (non-ground)
# Downsampled from (191923, 3) to (2785, 3) points (ground)
# Downsampled from (85024, 3) to (1185, 3) points (non-ground)
# Downsampled from (175420, 3) to (2612, 3) points (ground)
# Downsampled from (93553, 3) to (1645, 3) points (non-ground)
# Downsampled from (168382, 3) to (2806, 3) points (ground)
# Downsampled from (133826, 3) to (2445, 3) points (non-ground)
# Downsampled from (145365, 3) to (2741, 3) points (ground)
# Downsampled from (158312, 3) to (2546, 3) points (non-ground)
# Downsampled from (150057, 3) to (2854, 3) points (ground)
# Downsampled from (147655, 3) to (2341, 3) points (non-ground)
# Downsampled from (155970, 3) to (2834, 3) points (ground)
# Downsampled from (113206, 3) to (1756, 3) points (non-ground)
# Downsampled from (169495, 3) to (2665, 3) points (ground)
# Downsampled from (158082, 3) to (2273, 3) points (non-ground)
# Downsampled from (181799, 3) to (2513, 3) points (ground)
# Downsampled from (198907, 3) to (2781, 3) points (non-ground)
# Downsampled from (208707, 3) to (3071, 3) points (ground)
# Downsampled from (165714, 3) to (2361, 3) points (non-ground)
# Downsampled from (204220, 3) to (2633, 3) points (ground)
# Downsampled from (66055, 3) to (895, 3) points (non-ground)
# Downsampled from (206019, 3) to (2910, 3) points (ground)
# Downsampled from (115762, 3) to (1733, 3) points (non-ground)
# Downsampled from (195602, 3) to (2882, 3) points (ground)
# Downsampled from (91429, 3) to (1600, 3) points (non-ground)
# Downsampled from (184305, 3) to (2769, 3) points (ground)
# Downsampled from (57078, 3) to (1302, 3) points (non-ground)
# Downsampled from (176617, 3) to (2638, 3) points (ground)
# Downsampled from (87681, 3) to (1598, 3) points (non-ground)
# Downsampled from (166683, 3) to (2648, 3) points (ground)
# Downsampled from (74791, 3) to (1520, 3) points (non-ground)
# Downsampled from (156289, 3) to (2565, 3) points (ground)
# Downsampled from (56427, 3) to (1391, 3) points (non-ground)
# Downsampled from (158595, 3) to (2625, 3) points (ground)
# Downsampled from (60746, 3) to (1630, 3) points (non-ground)
# Downsampled from (159120, 3) to (2533, 3) points (ground)
# Downsampled from (114863, 3) to (2179, 3) points (non-ground)
# Downsampled from (149041, 3) to (2296, 3) points (ground)
# Downsampled from (125030, 3) to (2491, 3) points (non-ground)
# Downsampled from (150587, 3) to (2428, 3) points (ground)
# Downsampled from (109277, 3) to (2282, 3) points (non-ground)
# Downsampled from (157036, 3) to (2657, 3) points (ground)
# Downsampled from (112521, 3) to (2444, 3) points (non-ground)
# Downsampled from (144829, 3) to (2670, 3) points (ground)
# Downsampled from (86922, 3) to (1918, 3) points (non-ground)
# Downsampled from (130748, 3) to (2726, 3) points (ground)
# Downsampled from (114168, 3) to (2412, 3) points (non-ground)
# Downsampled from (128155, 3) to (2500, 3) points (ground)
# Downsampled from (140089, 3) to (2675, 3) points (non-ground)
# Downsampled from (130077, 3) to (2673, 3) points (ground)
# Downsampled from (123451, 3) to (2276, 3) points (non-ground)
# Downsampled from (133693, 3) to (2579, 3) points (ground)
# Downsampled from (139651, 3) to (2641, 3) points (non-ground)
# Downsampled from (132016, 3) to (2461, 3) points (ground)
# Downsampled from (137549, 3) to (2519, 3) points (non-ground)
# Downsampled from (127076, 3) to (2446, 3) points (ground)
# Downsampled from (122864, 3) to (2276, 3) points (non-ground)
# Downsampled from (130521, 3) to (2489, 3) points (ground)
# Downsampled from (178244, 3) to (2958, 3) points (non-ground)
# Downsampled from (120610, 3) to (2310, 3) points (ground)
# Downsampled from (167129, 3) to (3003, 3) points (non-ground)
# Downsampled from (128267, 3) to (2205, 3) points (ground)
# Downsampled from (106415, 3) to (2284, 3) points (non-ground)
# Downsampled from (128666, 3) to (2299, 3) points (ground)
# Downsampled from (93476, 3) to (2049, 3) points (non-ground)
# Downsampled from (132654, 3) to (2353, 3) points (ground)
# Downsampled from (113601, 3) to (1916, 3) points (non-ground)
# Downsampled from (122539, 3) to (2108, 3) points (ground)
# Downsampled from (117756, 3) to (1913, 3) points (non-ground)
# Downsampled from (121940, 3) to (2062, 3) points (ground)
# Downsampled from (119125, 3) to (1804, 3) points (non-ground)
# Downsampled from (166861, 3) to (2373, 3) points (ground)
# Downsampled from (109770, 3) to (2203, 3) points (non-ground)
# Downsampled from (224585, 3) to (2776, 3) points (ground)
# Downsampled from (147579, 3) to (2541, 3) points (non-ground)
# Downsampled from (257650, 3) to (2754, 3) points (ground)
# Downsampled from (29076, 3) to (895, 3) points (non-ground)
# Downsampled from (261933, 3) to (3188, 3) points (ground)
# Downsampled from (9575, 3) to (522, 3) points (non-ground)
# Downsampled from (260043, 3) to (2840, 3) points (ground)
# Downsampled from (59994, 3) to (962, 3) points (non-ground)
# Downsampled from (261520, 3) to (2638, 3) points (ground)
# Downsampled from (144621, 3) to (1826, 3) points (non-ground)
# Downsampled from (254507, 3) to (3297, 3) points (ground)
# Downsampled from (113427, 3) to (1525, 3) points (non-ground)
# Downsampled from (232952, 3) to (2873, 3) points (ground)
# Downsampled from (138220, 3) to (1686, 3) points (non-ground)
# Downsampled from (228705, 3) to (2930, 3) points (ground)
# Downsampled from (136294, 3) to (1701, 3) points (non-ground)
# Downsampled from (235860, 3) to (2952, 3) points (ground)
# Downsampled from (117625, 3) to (1614, 3) points (non-ground)
# Downsampled from (242382, 3) to (2931, 3) points (ground)
# Downsampled from (60432, 3) to (993, 3) points (non-ground)
# Downsampled from (255359, 3) to (3098, 3) points (ground)
# Downsampled from (50887, 3) to (919, 3) points (non-ground)
# Downsampled from (253967, 3) to (3078, 3) points (ground)
# Downsampled from (92624, 3) to (1382, 3) points (non-ground)
# Downsampled from (259181, 3) to (3061, 3) points (ground)
# Downsampled from (76948, 3) to (1193, 3) points (non-ground)
# Downsampled from (259054, 3) to (2966, 3) points (ground)
# Downsampled from (102852, 3) to (1441, 3) points (non-ground)
# Downsampled from (251490, 3) to (3234, 3) points (ground)
# Downsampled from (76940, 3) to (1073, 3) points (non-ground)
# Downsampled from (231589, 3) to (2817, 3) points (ground)
# Downsampled from (83433, 3) to (1143, 3) points (non-ground)
# Downsampled from (211701, 3) to (2814, 3) points (ground)
# Downsampled from (96741, 3) to (1357, 3) points (non-ground)
# Downsampled from (209534, 3) to (3053, 3) points (ground)
# Downsampled from (82100, 3) to (1113, 3) points (non-ground)
# Downsampled from (241994, 3) to (3332, 3) points (ground)
# Downsampled from (134451, 3) to (1797, 3) points (non-ground)
# Downsampled from (274551, 3) to (3552, 3) points (ground)
# Downsampled from (161599, 3) to (2059, 3) points (non-ground)
# Downsampled from (285529, 3) to (3622, 3) points (ground)
# Downsampled from (137175, 3) to (1769, 3) points (non-ground)
# Downsampled from (281923, 3) to (3361, 3) points (ground)
# Downsampled from (138517, 3) to (1609, 3) points (non-ground)
# Downsampled from (279168, 3) to (3148, 3) points (ground)
# Downsampled from (155714, 3) to (1458, 3) points (non-ground)
# Downsampled from (286667, 3) to (3044, 3) points (ground)
# Downsampled from (181628, 3) to (1801, 3) points (non-ground)
# Downsampled from (292092, 3) to (3073, 3) points (ground)
# Downsampled from (175080, 3) to (1702, 3) points (non-ground)
# Downsampled from (284244, 3) to (3130, 3) points (ground)
# Downsampled from (129173, 3) to (1441, 3) points (non-ground)
# Downsampled from (271895, 3) to (3137, 3) points (ground)
# Downsampled from (133715, 3) to (1591, 3) points (non-ground)
# Downsampled from (256472, 3) to (2947, 3) points (ground)
# Downsampled from (154332, 3) to (1886, 3) points (non-ground)
# Downsampled from (249574, 3) to (2918, 3) points (ground)
# Downsampled from (97326, 3) to (1519, 3) points (non-ground)
# Downsampled from (245986, 3) to (3207, 3) points (ground)
# Downsampled from (85591, 3) to (1261, 3) points (non-ground)
# Downsampled from (235806, 3) to (2961, 3) points (ground)
# Downsampled from (71042, 3) to (1214, 3) points (non-ground)
# Downsampled from (214498, 3) to (2860, 3) points (ground)
# Downsampled from (92010, 3) to (1353, 3) points (non-ground)
# Downsampled from (194226, 3) to (2730, 3) points (ground)
# Downsampled from (94678, 3) to (1404, 3) points (non-ground)
# Downsampled from (189534, 3) to (2892, 3) points (ground)
# Downsampled from (97375, 3) to (1371, 3) points (non-ground)
# Downsampled from (188981, 3) to (2757, 3) points (ground)
# Downsampled from (101224, 3) to (1295, 3) points (non-ground)
# Downsampled from (193383, 3) to (2775, 3) points (ground)
# Downsampled from (122372, 3) to (1472, 3) points (non-ground)
# Downsampled from (198443, 3) to (2757, 3) points (ground)
# Downsampled from (86414, 3) to (1066, 3) points (non-ground)
# Downsampled from (205016, 3) to (2919, 3) points (ground)
# Downsampled from (67528, 3) to (881, 3) points (non-ground)
# Downsampled from (206538, 3) to (2836, 3) points (ground)
# Downsampled from (58759, 3) to (741, 3) points (non-ground)
# Downsampled from (205427, 3) to (2734, 3) points (ground)
# Downsampled from (79985, 3) to (937, 3) points (non-ground)
# Downsampled from (204756, 3) to (2966, 3) points (ground)
# Downsampled from (89631, 3) to (1126, 3) points (non-ground)
# Downsampled from (201709, 3) to (2997, 3) points (ground)
# Downsampled from (88911, 3) to (1344, 3) points (non-ground)
# Downsampled from (197065, 3) to (2783, 3) points (ground)
# Downsampled from (72057, 3) to (1132, 3) points (non-ground)
# Downsampled from (194407, 3) to (2850, 3) points (ground)
# Downsampled from (52755, 3) to (890, 3) points (non-ground)
# Downsampled from (191650, 3) to (2795, 3) points (ground)
# Downsampled from (18015, 3) to (455, 3) points (non-ground)
# Downsampled from (187151, 3) to (2733, 3) points (ground)
# Downsampled from (22444, 3) to (573, 3) points (non-ground)
# Downsampled from (179858, 3) to (2860, 3) points (ground)
# Downsampled from (27873, 3) to (648, 3) points (non-ground)
# Downsampled from (155285, 3) to (2627, 3) points (ground)

# %%
for i,position in enumerate(center_positions) : 
	for j,position2 in enumerate(center_positions) : 
		if i != j : 
			dist = np.linalg.norm(position-position2)
			if dist < 22 : 
				print(dist)
			break
# Out:
# 7.285879045569875
# 7.285879045569875
# 14.307871145969928
# 18.920840510750402
# 11.97122236090938
# 5.967219060298385
# 9.641103807814012
# 16.619428796479298

# %%
def color_pcd_by_labels(pcd, labels,colors=None,gt_labels=None,semantics=False):
    
    if colors == None : 
        colors = generate_random_colors(2000)
    pcd_colored = copy.deepcopy(pcd)
    pcd_colors = np.zeros(np.asarray(pcd.points).shape)
    if gt_labels is None :
    	unique_labels = list(np.unique(labels)) 
    else: 
        unique_labels = list(np.unique(gt_labels))
    
    background_color = np.array([0,0,0])
    #for i in range(len(pcd_colored.points)):
    for i in unique_labels:
        if i == -1 : 
            continue
        idcs = np.where(labels == i)
        idcs = idcs[0]
        if i == 0 and semantics == False : 
            pcd_colors[idcs] = background_color
        else : 
            pcd_colors[idcs] = np.array(colors[unique_labels.index(i)])
        
    if semantics : 
        pcd_colored.colors = o3d.utility.Vector3dVector(pcd_colors)
    else : 
        pcd_colored.colors = o3d.utility.Vector3dVector(pcd_colors/255)
    return pcd_colored

# %%
def find_index_2d_list(my_list, target_sublist):
    for i, sublist in enumerate(my_list):
        if sublist == list(target_sublist): 
            return i
    return None  # Sublist not found in the list

# %%
def get_labels_from_cols(colors,labels,pcd):
	cur_cols = np.asarray(pcd.colors)
	unique_labels = list(np.unique(labels))
	new_labels = np.zeros_like(labels)
	for label in unique_labels: 
		idcs = np.where(labels == label)[0]
		col = cur_cols[idcs[0]]
		idx = find_index_2d_list(colors,col)
		new_labels[idcs] = idx 
	return new_labels

# %%
alpha = 1.0
theta = 0.5
colors = generate_random_colors_map(600)
beta = 0.0
gamma = 0.0
proximity_threshold = 1.0
ncuts_threshold = 0.03
out_name = 'tarl_spatial_short' + str(SEQUENCE_NUM)
# Generate 30 different colors
COLORS_arr = plt.cm.viridis(np.linspace(0, 1, 30)) 
COLORS = list(list(col) for col in COLORS_arr) 
COLORS = [list(col[:3]) for col in COLORS]

out_kitti_instance = out_chunks + 'out_kitti_instance_voxel' + str(SEQUENCE_NUM) + '/'
#if os.path.exists(out_kitti_instance) == True : 
#        shutil.rmtree(out_kitti_instance)
#os.makedirs(out_kitti_instance)

out_kitti_semantic = out_chunks + 'out_kitti_semantic_voxel' + str(SEQUENCE_NUM) + '/'
#if os.path.exists(out_kitti_semantic) == True : 
#        shutil.rmtree(out_kitti_semantic)
#os.makedirs(out_kitti_semantic)



limit = -1 ##use this for experiments to run limit chunks numberss


patchwise_indices = indices_per_patch(T_pcd, center_positions, positions, first_position, sampled_indices_global, chunk_size)
out_data = []
semantics = np.hstack((kitti_labels_orig['seg_nonground'].reshape(-1,),kitti_labels_orig['seg_ground'].reshape(-1,)))

instances = np.hstack((kitti_labels_orig['instance_nonground'],kitti_labels_orig['instance_ground']))
                
print("total sequence number",len(center_ids))
limit = 5
for sequence in range(1,limit):
        if NCUT_ground == False : 
                #o3d.visualization.draw_geometries([pcd_nonground_chunks[sequence]])
                merged_chunk,file_name, pcd_chunk, pcd_chunk_ground,inliers, inliers_ground = ncuts_chunk(dataset,list(indices),pcd_nonground_chunks,pcd_ground_chunks,
                        pcd_nonground_chunks_major_downsampling,
                        pcd_nonground_minor,T_pcd,center_positions,center_ids,
                        positions,first_position,list(sampled_indices_global),
                        chunk_size=chunk_size,major_voxel_size=major_voxel_size,
                        alpha=alpha,beta=beta,gamma=gamma,theta=theta,
                        proximity_threshold=proximity_threshold,
                        out_folder=out_folder_ncuts,ground_mode=False,sequence=sequence,
                        patchwise_indices=patchwise_indices,ncuts_threshold=ncuts_threshold)
                '''      
                ground_out,file_name = ncuts_chunk(dataset,list(indices_ground),pcd_chunk_ground,None,
                        pcd_ground_chunks_major_downsampling,
                        pcd_ground_minor,T_pcd,center_positions,center_ids,
                        positions,first_position,list(sampled_indices_global),
                        chunk_size=chunk_size,major_voxel_size=major_voxel_size,
                        alpha=1.0,beta=2.0,gamma=0.0,theta=0.0,
                        proximity_threshold=20.0,
                        out_folder=out_folder_ncuts,ground_mode=True,sequence=sequence,
                        patchwise_indices=patchwise_indices,ncuts_threshold=0.2)
                
                o3d.visualization.draw_geometries([ground_out])
                '''
                seg_ground = kitti_labels['ground']['semantic'][sequence][inliers][inliers_ground]
                inst_ground = kitti_labels['ground']['instance'][sequence][inliers][inliers_ground]
                
                file_name = str(center_ids[sequence]).zfill(6) + '.pcd'

                kitti_chunk = color_pcd_by_labels(pcd_chunk,kitti_labels['nonground']['semantic'][sequence].reshape(-1,),
                                        colors=COLORS,gt_labels=semantics,semantics=True)
                
                kitti_chunk_instance = color_pcd_by_labels(pcd_chunk,kitti_labels['nonground']['instance'][sequence].reshape(-1,),
                                        colors=colors,gt_labels=instances)
                                        
                kitti_chunk_instance_ground = color_pcd_by_labels(pcd_chunk_ground,inst_ground.reshape(-1,),
                                        colors=colors,gt_labels=instances)
                                        
                kitti_chunk_semantic_ground = color_pcd_by_labels(pcd_chunk_ground,seg_ground.reshape(-1,),
                                        colors=COLORS,gt_labels=semantics,semantics=True)
                
                #o3d.visualization.draw_geometries([kitti_chunk_instance + kitti_chunk_instance_ground])
                #o3d.visualization.draw_geometries([pcd_chunk + pcd_chunk_ground])
                semantic_labels = np.hstack(( kitti_labels['nonground']['semantic'][sequence].reshape(-1,),seg_ground.reshape(-1,)))
                np.savez(out_kitti_semantic + file_name.split('.')[0] + '.npz',labels=semantic_labels)
                
                o3d.io.write_point_cloud(out_folder_ncuts + file_name, pcd_chunk + pcd_chunk_ground , write_ascii=False, compressed=False, print_progress=False)
                o3d.io.write_point_cloud(out_kitti_instance + file_name, kitti_chunk_instance + kitti_chunk_instance_ground, write_ascii=False, compressed=False, print_progress=False)
# Out:
# total sequence number 91
# Start of sequence 1
# 3596 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 18 cut regions
# Ratio of points in top 3 groups: 0.8328698553948832
# Start of sequence 1
# 1516 points in downsampled chunk (major)
# Adjacency Matrix built
# 0 isolated points removed
# Start of normalized Cuts
# There are 7 cut regions
# Ratio of points in top 3 groups: 0.7631926121372031

# %%
def get_merge_pcds(out_folder_ncuts):
        point_clouds = []

        # List all files in the folder
        files = os.listdir(out_folder_ncuts)
        files.sort()

        # Filter files with a .pcd extension
        pcd_files = [file for file in files if file.endswith(".pcd")]
        print(pcd_files)
        # Load each point cloud and append to the list
        for pcd_file in pcd_files:
                file_path = os.path.join(out_folder_ncuts, pcd_file)
                point_cloud = o3d.io.read_point_cloud(file_path)
                point_clouds.append(point_cloud)
        return point_clouds




def merge_unite_gt(chunks):
    last_chunk = chunks[0] 
    merge = o3d.geometry.PointCloud()
    merge += last_chunk

    for new_chunk in chunks[1:]:
        merge += new_chunk
    
    merge.remove_duplicated_points()
    return merge

# %%
out_dbscan = out_chunks + 'out_ncuts/'
out_kitti = out_chunks + 'out_kitti' + str(SEQUENCE_NUM) + '/'
out_kitti_instance = out_chunks + 'out_kitti_instance_voxel' + str(SEQUENCE_NUM) + '/'
out_kitti_semantic = out_chunks + 'out_kitti_semantic_voxel' + str(SEQUENCE_NUM) + '/'


point_clouds = get_merge_pcds(out_folder_ncuts)[:limit]
point_clouds_kitti = get_merge_pcds(out_kitti_instance)[:limit]
merge = merge_chunks_unite_instances(point_clouds)
instance_gt = merge_unite_gt(point_clouds_kitti)
o3d.visualization.draw_geometries([merge])

o3d.io.write_point_cloud(out_folder + "merge_part_kitti_instance_voxel" + str(major_voxel_size) + '_' +  str(SEQUENCE_NUM) + '.pcd',instance_gt, write_ascii=False, compressed=False, print_progress=False)
o3d.io.write_point_cloud(out_folder + out_name + str(SEQUENCE_NUM) + ".pcd", merge, write_ascii=False, compressed=False, print_progress=False)
# Out:
# ['000055.pcd', '000066.pcd', '000075.pcd', '000084.pcd']
# ['000042.pcd', '000055.pcd', '000066.pcd', '000075.pcd', '000084.pcd', '000093.pcd', '000102.pcd', '000113.pcd', '000125.pcd', '000141.pcd', '000153.pcd', '000163.pcd', '000173.pcd', '000183.pcd', '000193.pcd', '000202.pcd', '000211.pcd', '000220.pcd', '000229.pcd', '000239.pcd', '000249.pcd', '000259.pcd', '000269.pcd', '000279.pcd', '000290.pcd', '000311.pcd', '000338.pcd', '000351.pcd', '000361.pcd', '000369.pcd', '000377.pcd', '000385.pcd', '000393.pcd', '000401.pcd', '000409.pcd', '000417.pcd', '000425.pcd', '000434.pcd', '000445.pcd', '000457.pcd', '000473.pcd', '000488.pcd', '000501.pcd', '000511.pcd', '000519.pcd', '000528.pcd', '000536.pcd', '000545.pcd', '000554.pcd', '000562.pcd', '000569.pcd', '000576.pcd', '000583.pcd', '000591.pcd', '000598.pcd', '000606.pcd', '000614.pcd', '000623.pcd', '000635.pcd', '000740.pcd', '000759.pcd', '000769.pcd', '000777.pcd', '000784.pcd', '000790.pcd', '000796.pcd', '000802.pcd', '000809.pcd', '000816.pcd', '000823.pcd', '000830.pcd', '000837.pcd', '000844.pcd', '000851.pcd', '000858.pcd', '000865.pcd', '000872.pcd', '000880.pcd', '000890.pcd', '000905.pcd', '000921.pcd', '000933.pcd', '000943.pcd', '000953.pcd', '000963.pcd', '000974.pcd', '000986.pcd', '001001.pcd', '001026.pcd', '001057.pcd', '001076.pcd']
# True

# %%
'''
optional cell for loading stored files
import open3d as o3d

out_folder = 'pcd_preprocessed/'
merge = o3d.io.read_point_cloud(out_folder + 'merge_part.pcd')
merge_dbscan = o3d.io.read_point_cloud(out_folder + 'merge_part_dbscan.pcd')
merge_kitti = o3d.io.read_point_cloud(out_folder + 'merge_part_kitti.pcd')
merge_kitti_instance = o3d.io.read_point_cloud(out_folder + 'merge_part_kitti_instance.pcd')
merge_exp2 = o3d.io.read_point_cloud(out_folder + 'merge_exp2.pcd')

print(merge)
print(merge_kitti)
print(merge_exp2)
'''
# Out:
# "\noptional cell for loading stored files\nimport open3d as o3d\n\nout_folder = 'pcd_preprocessed/'\nmerge = o3d.io.read_point_cloud(out_folder + 'merge_part.pcd')\nmerge_dbscan = o3d.io.read_point_cloud(out_folder + 'merge_part_dbscan.pcd')\nmerge_kitti = o3d.io.read_point_cloud(out_folder + 'merge_part_kitti.pcd')\nmerge_kitti_instance = o3d.io.read_point_cloud(out_folder + 'merge_part_kitti_instance.pcd')\nmerge_exp2 = o3d.io.read_point_cloud(out_folder + 'merge_exp2.pcd')\n\nprint(merge)\nprint(merge_kitti)\nprint(merge_exp2)\n"

# %%
from tqdm import tqdm 

merge = o3d.io.read_point_cloud(out_folder + out_name + str(SEQUENCE_NUM) +  ".pcd")
unique_colors, labels_ncuts = np.unique(np.asarray(merge.colors), axis=0, return_inverse=True)
merge_kitti_instance = o3d.io.read_point_cloud(out_folder + "merge_part_kitti_instance_voxel" + str(major_voxel_size) + '_' + str(SEQUENCE_NUM) +  ".pcd")
unique_colors, labels_kitti = np.unique(np.asarray(merge_kitti_instance.colors),axis=0, return_inverse=True)

def intersect(pred_indices, gt_indices):
        intersection = np.intersect1d(pred_indices, gt_indices)
        return intersection.size / pred_indices.shape[0]


from concurrent.futures import ThreadPoolExecutor

def process_batch(unique_pred, preds, labels, gt_idcs, threshold, new_ncuts_labels):
    pred_idcs = np.where(preds == unique_pred)[0]
    cur_intersect = np.sum(np.isin(pred_idcs, gt_idcs))
    if cur_intersect > threshold * len(pred_idcs): 
        new_ncuts_labels[pred_idcs] = 0

def remove_semantics(labels, preds, threshold=0.8, num_threads=None):
    gt_idcs = np.where(labels == 0)[0]
    new_ncuts_labels = preds.copy()
    unique_preds = np.unique(preds)
    
    if num_threads is None:
        num_threads = min(len(unique_preds), 8)  # Default to 8 threads if not specified
    
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        futures = []
        for i in tqdm(unique_preds):
            futures.append(executor.submit(process_batch, i, preds, labels, gt_idcs, threshold, new_ncuts_labels))
        
        # Wait for all tasks to complete
        for future in tqdm(futures, total=len(futures), desc="Processing"):
            future.result()  # Get the result to catch any exceptions
        
    return new_ncuts_labels

print('remove semantics')
new_ncuts_labels = remove_semantics(labels_kitti,labels_ncuts)


metrics_ncuts = Metrics(name='ncuts')

metrics_ncuts.update_stats(labels_ncuts,new_ncuts_labels,labels_kitti)

#merge_vis = color_pcd_by_labels(merge,new_ncuts_labels)
#o3d.visualization.draw_geometries([merge_vis])
# Out:
# remove semantics
# 100%|██████████| 73/73 [00:00<00:00, 25283.58it/s]
# Processing: 100%|██████████| 73/73 [00:00<00:00, 183.86it/s]
# Metrics for file ncuts
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/cedric/unsup_3d_instances/point-to-pixel-mapping/example_dataset_generation_out_refactor copy.ipynb Cell 24 line 4
#      <a href='vscode-notebook-cell:/home/cedric/unsup_3d_instances/point-to-pixel-mapping/example_dataset_generation_out_refactor%20copy.ipynb#X31sZmlsZQ%3D%3D?line=40'>41</a> new_ncuts_labels = remove_semantics(labels_kitti,labels_ncuts)
#      <a href='vscode-notebook-cell:/home/cedric/unsup_3d_instances/point-to-pixel-mapping/example_dataset_generation_out_refactor%20copy.ipynb#X31sZmlsZQ%3D%3D?line=43'>44</a> metrics_ncuts = Metrics(name='ncuts')
# ---> <a href='vscode-notebook-cell:/home/cedric/unsup_3d_instances/point-to-pixel-mapping/example_dataset_generation_out_refactor%20copy.ipynb#X31sZmlsZQ%3D%3D?line=45'>46</a> metrics_ncuts.update_stats(labels_ncuts,new_ncuts_labels,labels_kitti)
#      <a href='vscode-notebook-cell:/home/cedric/unsup_3d_instances/point-to-pixel-mapping/example_dataset_generation_out_refactor%20copy.ipynb#X31sZmlsZQ%3D%3D?line=47'>48</a> #merge_vis = color_pcd_by_labels(merge,new_ncuts_labels)
#      <a href='vscode-notebook-cell:/home/cedric/unsup_3d_instances/point-to-pixel-mapping/example_dataset_generation_out_refactor%20copy.ipynb#X31sZmlsZQ%3D%3D?line=48'>49</a> #o3d.visualization.draw_geometries([merge_vis])
#
# File ~/unsup_3d_instances/point-to-pixel-mapping/metrics/metrics_class.py:229, in Metrics.update_stats(self, all_labels, pred_labels, gt_labels, confs, calc_all, calc_lstq)
#     227 pred_labels = self.filter_labels(pred_labels)
#     228 if calc_all:
# --> 229     self.calculate_full_stats(pred_labels, gt_labels)
#     230 if calc_lstq:
#     231     self.eval_lstq.add_batch(all_labels, gt_labels)
#
# File ~/unsup_3d_instances/point-to-pixel-mapping/metrics/metrics_class.py:379, in Metrics.calculate_full_stats(self, pred_indices, gt_indices)
#     378 def calculate_full_stats(self, pred_indices, gt_indices):
# --> 379     out = full_statistics(
#     380         pred_indices,
#     381         gt_indices,
#     382         instanseg.metrics.iou,
#     383         'iou')
#     384     print(out)
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/instanseg/metrics/full_statistics.py:43, in full_statistics(pred_labels, gt_labels, metric, tp_condition)
#      26 def full_statistics(
#      27     pred_labels: NDArray[Any, np.int32],
#      28     gt_labels: NDArray[Any, np.int32],
#    (...)
#      33     tp_condition: str,
#      34 ) -> Dict[str, float]:
#      35     """
#      36     :param pred_labels: array containing the labels of points obtained as a result of segmentation
#      37     :param gt_labels: array containing the reference labels of point cloud
#    (...)
#      41     :return: dictionary with all supported instance detection metric names and their values
#      42     """
# ---> 43     __pred_gt_assert(pred_labels, gt_labels)
#      44     __tp_condition_assert(tp_condition)
#      46     mean_result = __mean(pred_labels, gt_labels, metric, tp_condition)
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/instanseg/utils/check_input.py:43, in __pred_gt_assert(pred_labels, gt_labels, require_equal_sizes)
#      39 assert (
#      40     pred_labels.size + gt_labels.size != 0
#      41 ), "Prediction and ground truth array sizes must be positive"
#      42 if require_equal_sizes:
# ---> 43     assert (
#      44         pred_labels.size == gt_labels.size
#      45     ), "Prediction and ground truth array sizes must be equals"
#
# AssertionError: Prediction and ground truth array sizes must be equals

# %%
o3d.visualization.draw_geometries([merge])

# %% [markdown]
# Result of 0.35 :
# 'panoptic': 0.7094522002293194, 'precision': 0.8148148148148148, 'recall': 0.8073394495412844, 'fScore': 0.8110599078341013
# AP @ 0.25 75.637
# AP @ 0.5 60.418
# AP @ [0.5:0.95] 42.78

# %% [markdown]
# Result of 0.25 (1):
# 'panoptic': 0.6819569021982189, 'precision': 0.8404255319148937, 'recall': 0.7247706422018348, 'fScore': 0.7783251231527094
# AP @ 0.25 74.031
# AP @ 0.5 56.422
# AP @ [0.5:0.95] 39.405
